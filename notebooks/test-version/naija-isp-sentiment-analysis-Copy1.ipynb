# %% [markdown]
# <a href="https://colab.research.google.com/github/Korede2001/Capstone/blob/main/Nigerian_ISP_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nigerian ISP Sentiment Analysis Pipeline (18/06/2021)
# -First Build-
#
# **`Objectives:`**
# - Setup a working sentiment analysis pipeline with basic functionality as provided by sentiment analysis libraries
# - Build familiarity with the Twitter API
# - Diagnose issues with publicly available sentiment analysizers when working with Nigerian data.
#
# **`Key Findings:`**
# - Accounting for Pidgin English and slangs is very important if we are to properly classify tweets.
# - Find a way to pinpoint the target/subject of words in a tweet to avoid misattribution of positive/negative words.
# - How do we handle connotations of sentences? E.g. Get IPNX! This will be an interesting one to tackle, and I can definitely see such connotative sentences coming up very frequently.

# %% [markdown]
# ### 1. Library Importation

# %%
#Import relevant libraries
import tweepy
import pandas as pd
import numpy as np
import textblob

# %% [markdown]
# ### 2. Setting up & connecting to the API

# %%
#Import the twitter credentials stored in a separate file
# %run ./twitter_credentials

# %%
#Create the authentication object
auth = tweepy.OAuthHandler(api_key,api_secret_key)

#Set the access token and access token secret
auth.set_access_token(access_token,access_token_secret)

#Create the API object
api = tweepy.API(auth)

#wait_on_rate_limit = True

# %% [markdown]
# ### 2. Extracting the Tweets
# #### Specifying the tweet search parameters
#
# Note: I comment out to avoid rerunning and wasting my limited tweets

# %%
#Specify Lagos state geocode
#lagos_geocode = "6.5244,3.3792,500km"

#Specify the development environment (needed to access the full archive)
#dev_env = 'prod'


##SPECTRANET ISP

#Tweets containing 'spectranet' and exclude tweets from the official ISP Twitter handle
#These will be narrowed down to tweets in Lagos using the geocode
#spectranet_query = 'spectranet -from:spectranet_NG'

##IPNX ISP

#Tweets containing 'IPNX' and exclude tweets from the official ISP Twitter handles
#place argument narrows to Lagos, Nigeria
#IPNX_query = 'IPNX -from:ipNXTweet -from:IpnxSupport place:Lagos'

# %% [markdown]
# #### Fetching the tweets
#
# Full archive search (which allows me to get tweets from previous years) actually works! Only, I have a lower limit of 5k tweets per month. The limit can definitely be worked with.

# %%
#Get tweets for Spectranet ISP. Defaults to 15 tweets
#spectranet_tweets = api.search(q = spectranet_query, geocode = lagos_geocode)

#Full archive search for IPNX tweets (This actually works!)
#IPNX_tweets = api.search_full_archive(dev_env, IPNX_query, fromDate = '202001010000', toDate='202012312359')

# %% [markdown]
# #### Sample texts from the tweets

# %% [markdown]
# **Spectranet:**

# %% [markdown]
# for num,tweet in enumerate(spectranet_tweets[:5]):
#     print(num+1, '-' ,tweet.text + '\n')

# %% [markdown]
# **IPNX:**

# %%
for num,tweet in enumerate(IPNX_tweets[:6]):
    print(num+1, '-' ,tweet.text + '\n')
# Out:
# 1 - @adefola09 They said they don’t have coverage at my side oo... thinking of getting ipnx
#
# 2 - @Olufems Yes. IPNX
#
# 3 - @fkabudu ipNX has never disgraced me, if they’re available in your area check them out.
#
# 4 - Here we go, Public School Students In Oyo Now Have 24hrs Access To Internet! @seyiamakinde @thecableng @ipNXTweet… https://t.co/pe8eAhU3bD
#
# 5 - @tundealuko Still wondering how IPNX said we used 330gb in 7 days .... average of 35-50gb per day
#
# 6 - Tizeti , pay for 1 month enjoy 5 days disconnected for 7days then reconnected for 3 then disconnected for 4days the… https://t.co/dhUEd71g4x

# %% [markdown]
# #### Compiling the tweets

# %% [markdown]
# #Getting the relevant properties from the tweets
# tweets = [{'Time':tweet.created_at, 'Subject':'Spectranet', 'Text':tweet.text,
#           'Coordinates':tweet.coordinates, 'Place': tweet.place, 'Source':tweet.source
#           } for tweet in spectranet_tweets]
#
# #Add the IPNX tweets to tweets list
# tweets.extend([{'Time':tweet.created_at, 'Subject':'IPNX', 'Text':tweet.text,
#                 'Coordinates':tweet.coordinates, 'Place': tweet.place, 'Source':tweet.source
#           } for tweet in IPNX_tweets])

# %% [markdown]
# df= pd.DataFrame.from_dict(tweets)
# df.to_csv('isp_tweets.csv',index=False)
# df.head()

# %%
#Convert to CSV to save current tweets obtained from the API
#df.to_csv('./isp_tweets.csv')

#df = pd.read_csv('isp_tweets.csv')

# %%
df = pd.read_csv('isp_tweets.csv', index_col=0)

# %%
df[-6:-1]
# Out:
#                    Time Subject  \
# 38  2020-06-12 14:27:48    IPNX
# 39  2020-06-11 00:42:40    IPNX
# 40  2020-06-09 23:23:13    IPNX
# 41  2020-05-07 15:28:07    IPNX
# 42  2020-03-28 20:36:39    IPNX
#
#                                                  Text Coordinates  \
# 38             @FurtherMaf F*ck Tizeti IPNX Way!!!!!!         NaN
# 39  @SheriphSkills Ipnx, the best. I don’t even us...         NaN
# 40                                 @kelonline Ipnx oh         NaN
# 41      Ipnx no dey fall hand https://t.co/vnFbqwYAup         NaN
# 42                              @MissIFY_ Ipnx maybe.         NaN
#
#                                                 Place               Source
# 38  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 39  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 40  Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 41  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 42  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone

# %%
#Make a copy of the dataframe to perform cleaning on
df2 = df.iloc[:28,:].copy()

# %% [markdown]
# ### 3. Data Cleaning & Preprocessing

# %%
#Remove links
df2['Text'] = df2['Text'].str.replace(r'https?:/+\S+','')

#Remove the @ symbol and newlines
df2['Text'] = df2['Text'].str.replace(r'@|\n','')

#Remove hashtags
df2['Text'] = df2['Text'].str.replace(r'#\w+','')

for tweet in df2['Text']:
  print(tweet,'\n')
# Out:
# Spectranet_NG stop tormenting my life with mails and text messages from you. abeg now! You have one job, fix your…
#
# Spectranet_NG Una No get level o...😑
#
# wohley_jnr iSlimfit Spectranet_NG Well it’s only a matter of time before they join. VPN Dey, we move 🚀
#
# Spectranet finally joined the ban 😂😂 but VPN to the rescue 🚀
#
# eesawa chico_shamsz Actually I’m using wifi(Spectranet). It’s like they only banned it via network providers, bec…
#
# Glo don receive am ooo. I no dey fit access twitter direct again. Na Spectranet I dey use direct. God knows if dem…
#
# Spectranet needs to understand its no turning back for me. lol
#
# Who can get me spectranet please?
#
# How did my Spectranet reset itself and how can I fix this without finding my LAN cable ? 🤦
#
# FBN_help Spectranet_NG Done
#
# Spectranet_NG Sent you a DM. Kindly reply. Thanks.
#
# MTNNG GloWorld AirtelNigeria Spectranet_NG
#
# adefola09 They said they don’t have coverage at my side oo... thinking of getting ipnx
#
# Olufems Yes. IPNX
#
# fkabudu ipNX has never disgraced me, if they’re available in your area check them out.
#
# Here we go, Public School Students In Oyo Now Have 24hrs Access To Internet! seyiamakinde thecableng ipNXTweet…
#
# tundealuko Still wondering how IPNX said we used 330gb in 7 days .... average of 35-50gb per day
#
# Tizeti , pay for 1 month enjoy 5 days disconnected for 7days then reconnected for 3 then disconnected for 4days the…
#
# IPNX finally in this estate. Ope o
#
# Lol glo nah war na... ipnx is the best
#
# itstopsss Ah... Use ipnx
#
# MrAdeWest Ah sucks. They’re really good. Or try ipnx
#
# FurtherMaf F*ck Tizeti IPNX Way!!!!!!
#
# SheriphSkills Ipnx, the best. I don’t even use DSTV again, just my Amazon firestick
#
# kelonline Ipnx oh
#
# Ipnx no dey fall hand
#
# MissIFY_ Ipnx maybe.
#
# Happy Mother's Day to Us all!   to ipNX FOS (Fibre Optic Service) for the  …
# /var/folders/j5/540q0bw12gx3g56qg4llbmlh0000gn/T/ipykernel_6395/178895068.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['Text'] = df2['Text'].str.replace(r'https?:/+\S+','')
# /var/folders/j5/540q0bw12gx3g56qg4llbmlh0000gn/T/ipykernel_6395/178895068.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['Text'] = df2['Text'].str.replace(r'@|\n','')
# /var/folders/j5/540q0bw12gx3g56qg4llbmlh0000gn/T/ipykernel_6395/178895068.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['Text'] = df2['Text'].str.replace(r'#\w+','')

# %% [markdown]
# ### 3. Sentiment Analysis

# %%
#We are not interested in how objective/subjective the sentence is so we focus
#on polarity
df2["Polarity"] = df2['Text'].apply(lambda x: textblob.TextBlob(x).sentiment.polarity)

# %%
df2
# Out:
#                    Time     Subject  \
# 0   2021-06-12 19:01:33  Spectranet
# 1   2021-06-05 20:20:39  Spectranet
# 2   2021-06-05 11:13:33  Spectranet
# 3   2021-06-05 11:12:06  Spectranet
# 4   2021-06-05 09:46:44  Spectranet
# 5   2021-06-05 05:10:10  Spectranet
# 6   2021-06-04 21:02:41  Spectranet
# 7   2021-06-01 15:00:10  Spectranet
# 8   2021-06-01 11:40:36  Spectranet
# 9   2021-06-01 10:37:56  Spectranet
# 10  2021-05-29 12:06:29  Spectranet
# 11  2021-05-23 09:08:05  Spectranet
# 12  2020-11-20 01:13:42  Spectranet
# 13  2020-11-18 13:03:55  Spectranet
# 14  2020-11-11 14:30:40  Spectranet
# 15  2020-10-17 06:46:31  Spectranet
# 16  2020-09-11 11:59:40  Spectranet
# 17  2020-08-13 18:01:05  Spectranet
# 18  2020-08-13 17:01:33  Spectranet
# 19  2020-06-26 13:24:04  Spectranet
# 20  2020-06-25 21:37:17  Spectranet
# 21  2020-06-21 21:08:02  Spectranet
# 22  2020-06-12 14:27:48  Spectranet
# 23  2020-06-11 00:42:40  Spectranet
# 24  2020-06-09 23:23:13  Spectranet
# 25  2020-05-07 15:28:07  Spectranet
# 26  2020-03-28 20:36:39  Spectranet
# 27  2020-03-22 13:35:27  Spectranet
#
#                                                  Text  \
# 0   Spectranet_NG stop tormenting my life with mai...
# 1                Spectranet_NG Una No get level o...😑
# 2   wohley_jnr iSlimfit Spectranet_NG Well it’s on...
# 3   Spectranet finally joined the ban 😂😂 but VPN t...
# 4   eesawa chico_shamsz Actually I’m using wifi(Sp...
# 5   Glo don receive am ooo. I no dey fit access tw...
# 6   Spectranet needs to understand its no turning ...
# 7                   Who can get me spectranet please?
# 8   How did my Spectranet reset itself and how can...
# 9                         FBN_help Spectranet_NG Done
# 10  Spectranet_NG Sent you a DM. Kindly reply. Tha...
# 11        MTNNG GloWorld AirtelNigeria Spectranet_NG
# 12  adefola09 They said they don’t have coverage a...
# 13                                  Olufems Yes. IPNX
# 14  fkabudu ipNX has never disgraced me, if they’r...
# 15  Here we go, Public School Students In Oyo Now ...
# 16  tundealuko Still wondering how IPNX said we us...
# 17  Tizeti , pay for 1 month enjoy 5 days disconne...
# 18                 IPNX finally in this estate. Ope o
# 19            Lol glo nah war na... ipnx is the best
# 20                           itstopsss Ah... Use ipnx
# 21  MrAdeWest Ah sucks. They’re really good. Or tr...
# 22              FurtherMaf F*ck Tizeti IPNX Way!!!!!!
# 23  SheriphSkills Ipnx, the best. I don’t even use...
# 24                                  kelonline Ipnx oh
# 25                             Ipnx no dey fall hand
# 26                               MissIFY_ Ipnx maybe.
# 27  Happy Mother's Day to Us all!   to ipNX FOS (F...
#
#                                           Coordinates  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  {'type': 'Point', 'coordinates': [3.39583, 6.4...
#
#                                                 Place               Source  \
# 0   Place(_api=<tweepy.api.API object at 0x7fe0862...      Twitter for Mac
# 1   Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 2   Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 3   Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 4   Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 5   Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 6   Place(_api=<tweepy.api.API object at 0x7fe0862...      Twitter for Mac
# 7   Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 8   Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 9   Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 10  Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 11  Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 12  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 13  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 14  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 15  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 16  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 17  Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 18  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 19  Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 20  Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 21  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 22  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 23  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 24  Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 25  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 26  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 27  Place(_api=<tweepy.api.API object at 0x7fe0862...            Instagram
#
#     Polarity
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.00
# 4       0.00
# 5       0.20
# 6       0.40
# 7       0.00
# 8       0.00
# 9       0.00
# 10      0.40
# 11      0.00
# 12      0.00
# 13      0.00
# 14      0.40
# 15      0.00
# 16     -0.15
# 17      0.40
# 18      0.00
# 19      0.90
# 20      0.00
# 21      0.20
# 22      0.00
# 23      1.00
# 24      0.00
# 25      0.00
# 26      0.00
# 27      1.00

# %%
def getSentiment(score):

  """
  Return the sentiment (positive, neutral or negative) based on the polarity score
  """

  if score < 0:
    return 'Negative'
  elif score == 0:
    return 'Neutral'
  else:
    return 'Positive'

df2['Sentiment'] = df2['Polarity'].apply(getSentiment)

# %%
df2
# Out:
#                    Time     Subject  \
# 0   2021-06-12 19:01:33  Spectranet
# 1   2021-06-05 20:20:39  Spectranet
# 2   2021-06-05 11:13:33  Spectranet
# 3   2021-06-05 11:12:06  Spectranet
# 4   2021-06-05 09:46:44  Spectranet
# 5   2021-06-05 05:10:10  Spectranet
# 6   2021-06-04 21:02:41  Spectranet
# 7   2021-06-01 15:00:10  Spectranet
# 8   2021-06-01 11:40:36  Spectranet
# 9   2021-06-01 10:37:56  Spectranet
# 10  2021-05-29 12:06:29  Spectranet
# 11  2021-05-23 09:08:05  Spectranet
# 12  2020-11-20 01:13:42  Spectranet
# 13  2020-11-18 13:03:55  Spectranet
# 14  2020-11-11 14:30:40  Spectranet
# 15  2020-10-17 06:46:31  Spectranet
# 16  2020-09-11 11:59:40  Spectranet
# 17  2020-08-13 18:01:05  Spectranet
# 18  2020-08-13 17:01:33  Spectranet
# 19  2020-06-26 13:24:04  Spectranet
# 20  2020-06-25 21:37:17  Spectranet
# 21  2020-06-21 21:08:02  Spectranet
# 22  2020-06-12 14:27:48  Spectranet
# 23  2020-06-11 00:42:40  Spectranet
# 24  2020-06-09 23:23:13  Spectranet
# 25  2020-05-07 15:28:07  Spectranet
# 26  2020-03-28 20:36:39  Spectranet
# 27  2020-03-22 13:35:27  Spectranet
#
#                                                  Text  \
# 0   Spectranet_NG stop tormenting my life with mai...
# 1                Spectranet_NG Una No get level o...😑
# 2   wohley_jnr iSlimfit Spectranet_NG Well it’s on...
# 3   Spectranet finally joined the ban 😂😂 but VPN t...
# 4   eesawa chico_shamsz Actually I’m using wifi(Sp...
# 5   Glo don receive am ooo. I no dey fit access tw...
# 6   Spectranet needs to understand its no turning ...
# 7                   Who can get me spectranet please?
# 8   How did my Spectranet reset itself and how can...
# 9                         FBN_help Spectranet_NG Done
# 10  Spectranet_NG Sent you a DM. Kindly reply. Tha...
# 11        MTNNG GloWorld AirtelNigeria Spectranet_NG
# 12  adefola09 They said they don’t have coverage a...
# 13                                  Olufems Yes. IPNX
# 14  fkabudu ipNX has never disgraced me, if they’r...
# 15  Here we go, Public School Students In Oyo Now ...
# 16  tundealuko Still wondering how IPNX said we us...
# 17  Tizeti , pay for 1 month enjoy 5 days disconne...
# 18                 IPNX finally in this estate. Ope o
# 19            Lol glo nah war na... ipnx is the best
# 20                           itstopsss Ah... Use ipnx
# 21  MrAdeWest Ah sucks. They’re really good. Or tr...
# 22              FurtherMaf F*ck Tizeti IPNX Way!!!!!!
# 23  SheriphSkills Ipnx, the best. I don’t even use...
# 24                                  kelonline Ipnx oh
# 25                             Ipnx no dey fall hand
# 26                               MissIFY_ Ipnx maybe.
# 27  Happy Mother's Day to Us all!   to ipNX FOS (F...
#
#                                           Coordinates  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  {'type': 'Point', 'coordinates': [3.39583, 6.4...
#
#                                                 Place               Source  \
# 0   Place(_api=<tweepy.api.API object at 0x7fe0862...      Twitter for Mac
# 1   Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 2   Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 3   Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 4   Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 5   Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 6   Place(_api=<tweepy.api.API object at 0x7fe0862...      Twitter for Mac
# 7   Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 8   Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 9   Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 10  Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 11  Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 12  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 13  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 14  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 15  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 16  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 17  Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 18  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 19  Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 20  Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 21  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 22  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 23  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 24  Place(_api=<tweepy.api.API object at 0x7fe0862...  Twitter for Android
# 25  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 26  Place(_api=<tweepy.api.API object at 0x7fe0862...   Twitter for iPhone
# 27  Place(_api=<tweepy.api.API object at 0x7fe0862...            Instagram
#
#     Polarity Sentiment
# 0       0.00   Neutral
# 1       0.00   Neutral
# 2       0.00   Neutral
# 3       0.00   Neutral
# 4       0.00   Neutral
# 5       0.20  Positive
# 6       0.40  Positive
# 7       0.00   Neutral
# 8       0.00   Neutral
# 9       0.00   Neutral
# 10      0.40  Positive
# 11      0.00   Neutral
# 12      0.00   Neutral
# 13      0.00   Neutral
# 14      0.40  Positive
# 15      0.00   Neutral
# 16     -0.15  Negative
# 17      0.40  Positive
# 18      0.00   Neutral
# 19      0.90  Positive
# 20      0.00   Neutral
# 21      0.20  Positive
# 22      0.00   Neutral
# 23      1.00  Positive
# 24      0.00   Neutral
# 25      0.00   Neutral
# 26      0.00   Neutral
# 27      1.00  Positive

# %% [markdown]
# ### 4. Validating Sentiment Results Manually
#
# I decided to go through each of the tweets and assign a sentiment myself. This could help diagnose issues the sentiment analyzer might be struggling with and suggest areas for improvement

# %%
my_sentiment_opinions = ['Negative','Negative','Neutral','Neutral','Neutral',
                         'Neutral','Neutral','Positive','Neutral','Neutral',
                         'Neutral','Neutral','Neutral','Neutral','Positive',
                         'Neutral','Negative','Neutral','Positive','Positive',
                         'Positive','Positive','Positive','Positive','Negative',
                         'Positive','Neutral','Neutral']

# %%
for opin,text in zip(my_sentiment_opinions,df2['Text']):
  print(opin,':',text)
# Out:
# Negative : Spectranet_NG stop tormenting my life with mails and text messages from you. abeg now! You have one job, fix your…
# Negative : Spectranet_NG Una No get level o...😑
# Neutral : wohley_jnr iSlimfit Spectranet_NG Well it’s only a matter of time before they join. VPN Dey, we move 🚀
# Neutral : Spectranet finally joined the ban 😂😂 but VPN to the rescue 🚀
# Neutral : eesawa chico_shamsz Actually I’m using wifi(Spectranet). It’s like they only banned it via network providers, bec…
# Neutral : Glo don receive am ooo. I no dey fit access twitter direct again. Na Spectranet I dey use direct. God knows if dem…
# Neutral : Spectranet needs to understand its no turning back for me. lol
# Positive : Who can get me spectranet please?
# Neutral : How did my Spectranet reset itself and how can I fix this without finding my LAN cable ? 🤦
# Neutral : FBN_help Spectranet_NG Done
# Neutral : Spectranet_NG Sent you a DM. Kindly reply. Thanks.
# Neutral : MTNNG GloWorld AirtelNigeria Spectranet_NG
# Neutral : adefola09 They said they don’t have coverage at my side oo... thinking of getting ipnx
# Neutral : Olufems Yes. IPNX
# Positive : fkabudu ipNX has never disgraced me, if they’re available in your area check them out.
# Neutral : Here we go, Public School Students In Oyo Now Have 24hrs Access To Internet! seyiamakinde thecableng ipNXTweet…
# Negative : tundealuko Still wondering how IPNX said we used 330gb in 7 days .... average of 35-50gb per day
# Neutral : Tizeti , pay for 1 month enjoy 5 days disconnected for 7days then reconnected for 3 then disconnected for 4days the…
# Positive : IPNX finally in this estate. Ope o
# Positive : Lol glo nah war na... ipnx is the best
# Positive : itstopsss Ah... Use ipnx
# Positive : MrAdeWest Ah sucks. They’re really good. Or try ipnx
# Positive : FurtherMaf F*ck Tizeti IPNX Way!!!!!!
# Positive : SheriphSkills Ipnx, the best. I don’t even use DSTV again, just my Amazon firestick
# Negative : kelonline Ipnx oh
# Positive : Ipnx no dey fall hand
# Neutral : MissIFY_ Ipnx maybe.
# Neutral : Happy Mother's Day to Us all!   to ipNX FOS (Fibre Optic Service) for the  …

# %%
#Add my sentiment opinions to the dataframe. This will be used for comparison
df2['My_Sentiment'] = my_sentiment_opinions

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# #### Looking in-depth at classifications

# %%
print(classification_report(df2['My_Sentiment'],df2['Sentiment']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       1.00      0.25      0.40         4
#      Neutral       0.56      0.67      0.61        15
#     Positive       0.44      0.44      0.44         9
#
#     accuracy                           0.54        28
#    macro avg       0.67      0.45      0.48        28
# weighted avg       0.58      0.54      0.52        28

# %% [markdown]
# #### Looking at a dataframe of the subsets

# %% [markdown]
# **Negative Tweets**

# %%
sentiment_subsets['negative']['subset']
# Out:
#                    Time     Subject  ... Sentiment My_Sentiment
# 0   2021-06-12 19:01:33  Spectranet  ...   Neutral     Negative
# 1   2021-06-05 20:20:39  Spectranet  ...   Neutral     Negative
# 16  2020-09-11 11:59:40        IPNX  ...  Negative     Negative
# 24  2020-06-09 23:23:13        IPNX  ...   Neutral     Negative
#
# [4 rows x 9 columns]

# %% [markdown]
# Textblob appears to fail because of the language. These tweets are in Nigerian lingo and Pidgin English and so, unsurprisingly, a sentiment analyzer built solely on English will struggle to accurately evaluate the sentiment of such tweets.

# %% [markdown]
# **Positive Tweets**

# %%
sentiment_subsets['positive']['subset']
# Out:
#                    Time     Subject  ... Sentiment My_Sentiment
# 7   2021-06-01 15:00:10  Spectranet  ...   Neutral     Positive
# 14  2020-11-11 14:30:40        IPNX  ...  Positive     Positive
# 18  2020-08-13 17:01:33        IPNX  ...   Neutral     Positive
# 19  2020-06-26 13:24:04        IPNX  ...  Positive     Positive
# 20  2020-06-25 21:37:17        IPNX  ...   Neutral     Positive
# 21  2020-06-21 21:08:02        IPNX  ...  Positive     Positive
# 22  2020-06-12 14:27:48        IPNX  ...   Neutral     Positive
# 23  2020-06-11 00:42:40        IPNX  ...  Positive     Positive
# 25  2020-05-07 15:28:07        IPNX  ...   Neutral     Positive
#
# [9 rows x 9 columns]

# %% [markdown]
# Here TextBlob misclassifies because it doesn't take into account the connotations of sentences (which objectively, likely carry no sentiment) e.g. who can get me spectranet? This implies that Spectranet is good and desirable. Textblob again also misclassifies because of the use of Pidgin English e.g. IPNX no dey fall hand, which translates to IPNX does not disappoint.

# %% [markdown]
# **Neutral Tweets**

# %%
sentiment_subsets['neutral']['subset']
# Out:
#                    Time     Subject  ... Sentiment My_Sentiment
# 2   2021-06-05 11:13:33  Spectranet  ...   Neutral      Neutral
# 3   2021-06-05 11:12:06  Spectranet  ...   Neutral      Neutral
# 4   2021-06-05 09:46:44  Spectranet  ...   Neutral      Neutral
# 5   2021-06-05 05:10:10  Spectranet  ...  Positive      Neutral
# 6   2021-06-04 21:02:41  Spectranet  ...  Positive      Neutral
# 8   2021-06-01 11:40:36  Spectranet  ...   Neutral      Neutral
# 9   2021-06-01 10:37:56  Spectranet  ...   Neutral      Neutral
# 10  2021-05-29 12:06:29  Spectranet  ...  Positive      Neutral
# 11  2021-05-23 09:08:05  Spectranet  ...   Neutral      Neutral
# 12  2020-11-20 01:13:42  Spectranet  ...   Neutral      Neutral
# 13  2020-11-18 13:03:55        IPNX  ...   Neutral      Neutral
# 15  2020-10-17 06:46:31        IPNX  ...   Neutral      Neutral
# 17  2020-08-13 18:01:05        IPNX  ...  Positive      Neutral
# 26  2020-03-28 20:36:39        IPNX  ...   Neutral      Neutral
# 27  2020-03-22 13:35:27        IPNX  ...  Positive      Neutral
#
# [15 rows x 9 columns]

# %% [markdown]
# Here TextBlob misclassifies because of misattribution. There are certain positive words in the sentence e.g. 'happy' in "Happy mother's day" or 'kindly' in "kindly reply", which do not directly relate to the ISP but are still present in the sentence. Again, it also misclassifies because of the use of pidgin English.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The sentiment analyzer can definitely be improved upon. Here are some important issues to look into:
#
# - Accounting for Pidgin English and slangs is very important if we are to properly classify tweets.
#
# - Find a way to pinpoint the target/subject of words in a tweet to avoid misattribution of positive/negative words.
#
# - How do we handle connotations of sentences? E.g. Get IPNX! This will be an interesting one to tackle, and I can definitely see such connotative sentences coming up very frequently.
