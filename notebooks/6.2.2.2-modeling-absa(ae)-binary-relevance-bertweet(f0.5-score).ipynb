# %% [markdown]
# # Modeling: Aspect-Based Sentiment Analysis
# ## Binary relevance approach
# *Using a combination of binary bertweet aspect classifiers for tweet aspect extractiom*

# %% [markdown]
# **`Overview:`**
#
# Attempts to build an accurate multi-label classifier which predicts all the aspects for a given tweet at the same time were fruitless (see 6.2.1). A popular problem transformation method for multi-label classification involves breaking down the problem into binary classification tasks. Here, the baseline approach, called the *binary relevance* method,amounts to independently training one binary classifier for each label/aspect. Given an unseen sample (tweet), the combined model then predicts all labels for this sample for which the respective classifiers predict a positive result.
#
# I experiment with the *binary relevance* approach below with particular interest in the following metrics:
# - Precision is the ability of the classifier not to label as positive a sample that is negative.
# - F-0.5 is a harmonic mean between precision and recall with more weight or importance being given to precision
#
# **`Initial results:`**
# - Solid performance on most label: F-0.5 score above 64% for all aspects except *price*
#
# **Note:** F-0.5 score was tracked in this notebook compared to F-1 score in the previous section (6.2.2.1). In the selection of best models, we look at both notebooks and determine which model is likely to have the better F-0.5 score. For the most part this has been a very clear question to answer.
#
#
# **`Best Models:`**
# Seems I forgot to save when I got the improved runs. What's important though is that I have the improved models
# - **Reliability (6.2.2.1 using F-1):** F-0.5 of 79.4%
# - **Coverage (can't find?):** F-0.5 of 82.23%
# - **Price (6.2.2.2 using F-0.5):** F-0.5 of 83.33%
# - **Speed (can't find?):** F-0.5 of 67.8%
# - **Customer Service (6.2.2.1 using F-1):** F-0.5 of 79.68%

# %% [markdown]
# ## 1. Library Importation

# %%
#Data manipulation and visualization packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#Modeling packages
import random
import torch
import tensorflow as tf
from tqdm.auto import tqdm
from torch.utils.data import Dataset, DataLoader
from transformers import Trainer, TrainingArguments
from transformers import TextClassificationPipeline
from transformers import AutoTokenizer, AutoModelForSequenceClassification

#Model evaluation and metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %% [markdown]
# ## 2. Set seed for reproducibility

# %%
def set_seed(seed: int):
    """
    Helper function for reproducible behavior to set the seed in random, numpy, 
    torch and/or tf (if installed).

    Args:
        seed (int): The seed to set.
        
    """
    
    #Set seed for random and numpy
    random.seed(seed)
    np.random.seed(seed)
    
    #Set torch seed
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    
    #Set seed for tensorflow
    tf.random.set_seed(seed)

        
#Set seed
RANDOM_SEED = 123
set_seed(RANDOM_SEED)

# %% [markdown]
# ## 3. Loading the data

# %%
#Load the dataframe with punctuated tweets. 
aspect_df = pd.read_csv("../data/processed/absa_text_annotated_price.csv")

#Load the dataframe from the 2nd absa annotation phase
#- Contains mostly tweets with aspect annotation (unlike the dataframe above)
aspect_df2 = pd.read_csv("../data/processed/second_tweet_absa_annotated.csv")

print(f"aspect_df size: {aspect_df.shape}")
print(f"aspect_df2 size: {aspect_df2.shape}")
# Out:
# aspect_df size: (377, 3)
# aspect_df2 size: (111, 4)

# %%
#Merge both dataframes together
merged_absa_df = pd.concat([aspect_df,aspect_df2.drop(columns = ['Cleaned tweets'])])
print(merged_absa_df.shape)
merged_absa_df.head()
# Out:
# (488, 3)
#                                                 Text               Aspects  \
# 0  my family used my spectranet and they don't wa...                   NaN
# 1  spectranet_ng how can i get the freedom mifi i...                   NaN
# 2           drolufunmilayo iconic_remi spectranet_ng                   NaN
# 3  spectranet_ng your response just proves how ho...  ['customer service']
# 4  spectranet is just the worse tbh, i can't even...             ['speed']
#
#       Sentiment
# 0           NaN
# 1           NaN
# 2           NaN
# 3  ['Negative']
# 4  ['Negative']

# %% [markdown]
# ## 4. Reformat the data

# %% [markdown]
# ### a. Convert lists from string format to list

# %%
#Convert Aspects column
merged_absa_df.Aspects = merged_absa_df.Aspects.apply(lambda x: eval(x) if (pd.notnull(x)) else x)

#Convert Sentiment column
merged_absa_df.Sentiment = merged_absa_df.Sentiment.apply(lambda x: eval(x) if (pd.notnull(x)) else x)

#Make a copy of the dataframe
processed_aspect_df = merged_absa_df.copy()

#Quick preview
processed_aspect_df.head()
# Out:
#                                                 Text             Aspects  \
# 0  my family used my spectranet and they don't wa...                 NaN
# 1  spectranet_ng how can i get the freedom mifi i...                 NaN
# 2           drolufunmilayo iconic_remi spectranet_ng                 NaN
# 3  spectranet_ng your response just proves how ho...  [customer service]
# 4  spectranet is just the worse tbh, i can't even...             [speed]
#
#     Sentiment
# 0         NaN
# 1         NaN
# 2         NaN
# 3  [Negative]
# 4  [Negative]

# %% [markdown]
# ### b. Fill NaNs with [None]

# %%
processed_aspect_df = processed_aspect_df.apply(lambda s: s.fillna({i: [None] for i in processed_aspect_df.index}))
processed_aspect_df.head()
# Out:
#                                                 Text             Aspects  \
# 0  my family used my spectranet and they don't wa...              [None]
# 1  spectranet_ng how can i get the freedom mifi i...              [None]
# 2           drolufunmilayo iconic_remi spectranet_ng              [None]
# 3  spectranet_ng your response just proves how ho...  [customer service]
# 4  spectranet is just the worse tbh, i can't even...             [speed]
#
#     Sentiment
# 0      [None]
# 1      [None]
# 2      [None]
# 3  [Negative]
# 4  [Negative]

# %% [markdown]
# ### c. Binarizing the aspects

# %%
#List aspects determined during the annotation phase
#Note: This might not be exhaustive! But it should cover most cases. It is also subjective!
#Also using synonyms of these words will likely yield different results
ASPECTS = ['price','speed','reliability','coverage', 'customer service']

#Iterate through all the aspects and if the aspect is not in the tweet, record 0 else record 1
for aspect in ASPECTS[::-1]:
    processed_aspect_df.insert(1,aspect,processed_aspect_df.Aspects.apply(lambda x: 1 if aspect in x else 0))
    
#Drop the Aspects column
processed_aspect_df.drop(columns=['Aspects'] , inplace=True)

#Quick preview
processed_aspect_df.head()
# Out:
#                                                 Text  price  speed  \
# 0  my family used my spectranet and they don't wa...      0      0
# 1  spectranet_ng how can i get the freedom mifi i...      0      0
# 2           drolufunmilayo iconic_remi spectranet_ng      0      0
# 3  spectranet_ng your response just proves how ho...      0      0
# 4  spectranet is just the worse tbh, i can't even...      0      1
#
#    reliability  coverage  customer service   Sentiment
# 0            0         0                 0      [None]
# 1            0         0                 0      [None]
# 2            0         0                 0      [None]
# 3            0         0                 1  [Negative]
# 4            0         0                 0  [Negative]

# %%
#Save the binarized dataframe
processed_aspect_df.to_csv("../data/processed/absa_binarized.csv",index=False)

# %% [markdown]
# ## 5. Quick EDA

# %%
with plt.style.context(['notebook','no-latex','grid']):
    plt.figure(figsize = (12,7), dpi=300)
    processed_aspect_df[ASPECTS].sum().sort_values()\
                                            .plot(kind = "barh", color = 'cornflowerblue')\
                                            .set(xlabel = "Number of times detected in tweets",
                                                ylabel = "Aspect category")
                        
    plt.show()

# %% [markdown]
# From the above, we see that the labels are quite imbalanced. To account for this, we look into reweighting our loss function. However, before doing so, we look more broadly into aspects vs no aspects tweets distribution:

# %%
#Get the rows with aspects tagged and no aspects tagged
aspects_tagged = processed_aspect_df[processed_aspect_df[ASPECTS].sum(axis=1) > 0]
no_aspects_tagged = processed_aspect_df[processed_aspect_df[ASPECTS].sum(axis=1) == 0]

with plt.style.context(['notebook','no-latex','grid']):
    plt.figure(figsize = (12,7), dpi=300)
    plt.barh(['Aspect(s) tagged','No aspect tagged'],
             [len(aspects_tagged),len(no_aspects_tagged)],color=['mediumslateblue','royalblue'])

# %% [markdown]
# Roughly balanced.

# %% [markdown]
# ## 6. Split data into training, validation and test set

# %% [markdown]
# ### a. Split to training and test set

# %%
#Split the data 80:20 (training and test)
train_df, test_df = train_test_split(processed_aspect_df,test_size=0.20,
                                    stratify = processed_aspect_df.coverage)
print(f"Train size: {train_df.shape}", f"Test size: {test_df.shape}")
# Out:
# Train size: (390, 7) Test size: (98, 7)

# %% [markdown]
# ### b. Split training set to training and validation set

# %%
train_df, val_df = train_test_split(train_df,test_size=0.25,
                                    stratify = train_df.coverage)
print(f"Train size: {train_df.shape}", f"Validation size: {val_df.shape}")
# Out:
# Train size: (292, 7) Validation size: (98, 7)

# %% [markdown]
# ### c. Check to see that all the sets have all the aspect categories

# %%
df_sets = [('Training',train_df),('Validation', val_df),('Test',test_df)]
    
plt.figure(figsize = (12,6))
for idx,df in enumerate(df_sets):
    
    plt.subplot(1,3,idx+1)
    plt.tight_layout()

    with plt.style.context(['notebook','no-latex','grid']):
        
        plt.title(df[0])
        df[1][ASPECTS].sum().plot(kind = "bar", color = 'cornflowerblue')
        plt.xticks(rotation=90)
        
        if idx == 0:
            plt.ylabel('Number of tags in the tweets', fontsize=16)
        
    
plt.show()

# %% [markdown]
# ## 7. Modeling - Aspect Extraction

# %% [markdown]
# ### a. Load the tokenizer and the BERTweet model

# %%
#Load BerTweet tokenizer
TOKENIZER = AutoTokenizer.from_pretrained("vinai/bertweet-base", normalization=True)

#Load the BERTweet model
BERTWEET_MODEL = AutoModelForSequenceClassification.from_pretrained("vinai/bertweet-base", 
                                                                    num_labels = 2, 
                                                                    from_tf = True)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2022-02-24 22:01:07.729124: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# All TF 2.0 model weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the TF 2.0 model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.

# %% [markdown]
# ### b. Define class to prepare training, validation and test datasets

# %%
class Generate_PyTorch_Dataset(torch.utils.data.Dataset):
    
    """
    Code adapted from NLPiation. (2021). 
    Is it possible to do Sentiment Analysis on unlabeled data using BERT? (Feat. Vader) [Experiment]. 
    https://nlpiation.medium.com/is-it-possible-to-do-sentiment-analysis-on-unlabeled-data-using-bert-feat-vader-experiment-357bba53768c

    """

    def __init__(self, texts, aspect_labels, tokenizer):
        self.texts      = texts
        self.labels     = aspect_labels
        self.tokenizer  = tokenizer
        self.max_len    = tokenizer.model_max_length
  
    def __len__(self):
        return len(self.texts)
  
    def __getitem__(self, idx):
        text = str(self.texts[idx])
        labels = self.labels[idx]

        encoded_text = self.tokenizer.encode_plus(
            text,
            add_special_tokens    = True,
            truncation            = True,
            return_attention_mask = True,
            return_token_type_ids = False,
            max_length            = self.max_len,
            return_tensors        = 'pt',
            padding               = "max_length"
        )

        return {
            'input_ids': encoded_text['input_ids'][0],
            'attention_mask': encoded_text['attention_mask'][0],
            'labels': torch.tensor(labels, dtype=torch.long)
        }

# %% [markdown]
# ### c. Define function to compute metrics for finetuning evaluation

# %%
def compute_metrics(eval_pred):
    
    """
    Function to compute accuracy metrics
    
    Input:
        - eval_pred (tuple): Tuple containing the model predictions and targets to be matched 
                             in the form: (predictions,targets)]
                             
    Output:
        - (dict): Dictionary containing different accuracy-related metrics
    
    """
    
    #Get the predicted labels and the true labels
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    
    #Compute, precision, recall, F-0.5 and accuracy score
    #We use binary here since for each binary relevance model we are mostly interested in the metric results
    #for the positive class (i.e. the aspect class predictions)
    #By using F-0.5 score, we incorportate the notion that precision is more valuable than recall on 
    #this scenario
    precision, recall, f_score, _ = precision_recall_fscore_support(labels, 
                                                                    predictions, 
                                                                    beta = 0.5,
                                                                    average='binary')
    
    return {'precision': precision,'recall': recall,'F-0.5': f_score}

# %% [markdown]
# ### d. Define general loss-reweighted model

# %%
class BinaryRelevanceTrainer(Trainer):
    
    """
    Class weighted trainer to account for imbalance
    """
    
    def __init__(self, no_of_classes, samples_per_cls, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.class_weights = self.get_ens_weights(no_of_classes, samples_per_cls)
        
    def get_ens_weights(self, no_of_classes,samples_per_cls,beta=0.99):
    
        """
        Compute class weights using effective number of samples strategy
        """

        effective_num = 1.0 - np.power(beta, samples_per_cls)
        weights = (1.0 - beta) / np.array(effective_num)
        weights = weights / np.sum(weights) * no_of_classes
        weights = torch.tensor(weights.astype(np.float32))
        
        return weights
    
    def compute_loss(self, model, inputs, return_outputs=False):
        
        labels = inputs.get("labels")
        #Forward pass
        outputs = model(**inputs)
        logits = outputs.get('logits')
        #Compute custom loss
        loss_fct = torch.nn.CrossEntropyLoss(weight= self.class_weights)
        loss = loss_fct(logits.view(-1, self.model.config.num_labels), labels.view(-1))
        return (loss, outputs) if return_outputs else loss

# %% [markdown]
# ### e. Define function to provide context into model's predictions

# %%
def get_summary_report(aspect: str,true_df,model_preds):
    
    """
    Create function to provide more context on the models precision and recall, or
    more generally its predictive performance in absolute terms
    
    Inputs:
        - aspect (str): Name of aspect in focus
        - true_df (pd series): A pandas series for the aspect's true (annotated) values
        - model_preds (np array): The models predictions for the corresponding tweets
    
    """
    
    #Get all true values
    true_array = np.array(true_df)
    #Get model predictions
    preds = np.argmax(model_preds[0], axis=1).flatten()

    #Calculate support
    support = sum(true_array)

    #Get positive predictions
    pos_preds_idx = np.argwhere(preds == 1)
    pos_preds = np.array([preds[i] for i in pos_preds_idx])
    #Get true values for the predictions
    true_values = np.array([true_array[i] for i in pos_preds_idx])

    print(f"- There were {support} {aspect} cases")
    print(f"- The model made {len(pos_preds)} predictions")
    print(f"- {sum(pos_preds == true_values)[0]} were accurate")

# %% [markdown]
# ---

# %% [markdown]
# ### Reliability Aspect Classifier

# %% [markdown]
# #### a. Encode the training, validation and test sets

# %%
#Prepare the Training set
reliability_train_dataset = Generate_PyTorch_Dataset(
    texts         = train_df.Text.tolist(),
    aspect_labels = train_df.reliability.tolist(),
    tokenizer     = TOKENIZER
)

#Prepare the validation set
reliability_val_dataset = Generate_PyTorch_Dataset(
    texts           = val_df.Text.tolist(),
    aspect_labels   = val_df.reliability.tolist(),
    tokenizer       = TOKENIZER
)

# Prepare the test set
reliability_test_dataset = Generate_PyTorch_Dataset(
    texts          = test_df.Text.tolist(),
    aspect_labels  = test_df.reliability.tolist(),
    tokenizer      = TOKENIZER
)

# %% [markdown]
# #### b. Training/finetuning the bertweet model for the reliability aspect
# We reweight the loss function given the extreme imbalance as shown below

# %%
with plt.style.context(['notebook','no-latex','grid']):
    train_df.reliability.value_counts().plot(kind='barh')
    plt.ylabel('Reliability aspect label', fontsize=16)
    plt.xlabel('Number of tweets', fontsize=16)

# %%
#Define the training parameters
reliability_training_args = TrainingArguments(
    output_dir                  = "../models/absa-aspect-extraction/ensemble_model/reliability_classifier",
    num_train_epochs            = 15,
    seed                        = 21,
    per_device_train_batch_size = 32, #Increase training batch size to ensure that each batch has a decent chance of containing a few positive samples.
    warmup_steps                = 500, #Add warmup steps since this is an entirely new problem domain for this pretrained model
    save_total_limit            = 3,
    load_best_model_at_end      = True,
    metric_for_best_model       = 'F-0.5',    
    save_strategy               = "epoch",
    logging_strategy            = "epoch",
    evaluation_strategy         = "epoch"
)    
    
#Define Trainer object
reliability_trainer = BinaryRelevanceTrainer(
    no_of_classes   = len(train_df.reliability.unique()),
    samples_per_cls = train_df.reliability.value_counts(sort=False).to_list(),
    model           = BERTWEET_MODEL,
    args            = reliability_training_args,
    train_dataset   = reliability_train_dataset,
    eval_dataset    = reliability_val_dataset,
    compute_metrics = compute_metrics
)


#Start pre-training!
reliability_trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 292
#   Num Epochs = 15
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 150
#     <div>
#
#       <progress value='150' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [150/150 1:13:19, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F-0.5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.698900</td>
#       <td>0.689483</td>
#       <td>0.192308</td>
#       <td>0.909091</td>
#       <td>0.228311</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.684300</td>
#       <td>0.665540</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.668800</td>
#       <td>0.632572</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.636200</td>
#       <td>0.603482</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.629600</td>
#       <td>0.576144</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.612200</td>
#       <td>0.559475</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.574900</td>
#       <td>0.541330</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.572800</td>
#       <td>0.510375</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.525500</td>
#       <td>0.472755</td>
#       <td>0.400000</td>
#       <td>0.363636</td>
#       <td>0.392157</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.394500</td>
#       <td>0.435144</td>
#       <td>0.375000</td>
#       <td>0.545455</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.267600</td>
#       <td>0.389011</td>
#       <td>0.388889</td>
#       <td>0.636364</td>
#       <td>0.421687</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.211900</td>
#       <td>0.455789</td>
#       <td>0.333333</td>
#       <td>0.909091</td>
#       <td>0.381679</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.197600</td>
#       <td>0.461379</td>
#       <td>0.800000</td>
#       <td>0.363636</td>
#       <td>0.645161</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.128000</td>
#       <td>0.384150</td>
#       <td>0.434783</td>
#       <td>0.909091</td>
#       <td>0.485437</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.063200</td>
#       <td>0.419145</td>
#       <td>0.434783</td>
#       <td>0.909091</td>
#       <td>0.485437</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-10
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-10/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-10/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-120] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-20
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-20/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-20/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-30
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-30/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-30/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-40
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-40/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-40/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-20] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-50
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-50/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-50/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-30] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-60
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-60/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-60/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-40] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-70
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-70/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-70/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-50] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-80
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-80/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-80/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-60] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-90
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-90/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-90/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-10] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-100
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-100/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-100/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-70] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-110
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-110/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-110/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-80] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-120
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-120/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-120/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-90] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-130
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-130/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-130/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-140
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-140/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-140/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-110] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-150
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-150/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-150/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-120] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-130 (score: 0.6451612903225806).
# TrainOutput(global_step=150, training_loss=0.4577433435122172, metrics={'train_runtime': 4426.998, 'train_samples_per_second': 0.989, 'train_steps_per_second': 0.034, 'total_flos': 453787081943040.0, 'train_loss': 0.4577433435122172, 'epoch': 15.0})

# %% [markdown]
# #### • Plot train and validation metrics

# %%
#Get the reliability bertweet's training logs
reliability_history = pd.DataFrame(reliability_trainer.state.log_history)
reliability_history.to_csv("../model_logs/aspect_extraction/reliability_bertweet_logs.csv",index=False)

reliability_history = pd.read_csv("../model_logs/aspect_extraction/reliability_bertweet_logs.csv")
reliability_history = reliability_history.fillna(method='bfill', 
                                                 limit=1).drop_duplicates(subset=['epoch','eval_loss'])

# %%
plt.figure(figsize=(15,9))

metrics = ['eval_loss','eval_F-0.5','eval_precision','eval_recall','eval_runtime']

for idx, metric in enumerate(metrics):
    with plt.style.context(['grid']):
        plt.tight_layout()
        ax = plt.subplot(3,2,idx+1).plot(reliability_history['epoch'],
                                         reliability_history[metric],
                                         label='validation')

        #Also plot training loss when plotting validation loss
        if metric == 'eval_loss':
            ax = plt.subplot(3,2,idx+1).plot(reliability_history['epoch'],
                                             reliability_history['loss'],
                                             color = ax[0].get_color(),
                                             linestyle= "--",
                                             label='training')

        plt.xlabel('Epoch', fontsize=12)
        plt.ylabel(metric.replace('eval_','').capitalize(),fontsize=12)
        plt.legend()

# %% [markdown]
# The model from Epoch 13 (**Checkpoint-130**) appears to have performed the best across all metrics. Especially on our metrics of interest: F-0.5 and precision.
#
# However, we note that the validation loss does not drop too significantly, meanwhile the training loss drops hugely. This might suggest that the model is overfitting in the training data.

# %% [markdown]
# #### • Load the best checkpoint

# %%
#Load the model
reliability_model = AutoModelForSequenceClassification.from_pretrained("../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-130")

reliability_pred_args = TrainingArguments(
    output_dir = "../model_predictions",
    do_eval = True
)

reliability_predictor = Trainer(
    model             = reliability_model,
    args              = reliability_pred_args,
    compute_metrics   = compute_metrics
)
# Out:
# loading configuration file ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-130/config.json
# Model config RobertaConfig {
#   "_name_or_path": "vinai/bertweet-base",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 130,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "tokenizer_class": "BertweetTokenizer",
#   "transformers_version": "4.8.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 64001
# }
#
# loading weights file ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-130/pytorch_model.bin
# All model checkpoint weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the model checkpoint at ../models/absa-aspect-extraction/ensemble_model/reliability_classifier/checkpoint-130.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %% [markdown]
# #### • Evaluating the model: How well does it classify tweets?

# %% [markdown]
# **Training set**

# %%
reliability_train = reliability_predictor.predict(reliability_train_dataset, metric_key_prefix= 'train')
reliability_train_df = pd.DataFrame([reliability_train[-1]])
reliability_train_df
# Out:
# ***** Running Prediction *****
#   Num examples = 292
#   Batch size = 8
#     <div>
#
#       <progress value='63' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [37/37 37:41]
#     </div>
#    train_loss  train_precision  train_recall  train_F-0.5  train_runtime  \
# 0    0.080794              1.0      0.894737     0.977011        85.2409
#
#    train_samples_per_second  train_steps_per_second
# 0                     3.426                   0.434

# %% [markdown]
# Did not successfully recall all the reliability aspect cases in the training set.

# %% [markdown]
# **Validation set**

# %%
reliability_validation = reliability_predictor.predict(reliability_val_dataset, metric_key_prefix= 'val')
reliability_validation_df = pd.DataFrame([reliability_validation[-1]])
reliability_validation_df
# Out:
# ***** Running Prediction *****
#   Num examples = 98
#   Batch size = 8
#    val_loss  val_precision  val_recall  val_F-0.5  val_runtime  \
# 0  0.262252            0.8    0.363636   0.645161      27.4705
#
#    val_samples_per_second  val_steps_per_second
# 0                   3.567                 0.473

# %% [markdown]
# Really poor recall. How many validation reliability cases were there actually? Based on this, 80% precision might not be too impressive:

# %%
get_summary_report('reliability',val_df.reliability,reliability_validation)
# Out:
# - There were 11 reliability cases
# - The model made 5 predictions
# - 4 were accurate

# %% [markdown]
# **Test set**

# %%
reliability_test = reliability_predictor.predict(reliability_test_dataset, metric_key_prefix= 'test')
pd.DataFrame([reliability_test[-1]])
# Out:
# ***** Running Prediction *****
#   Num examples = 98
#   Batch size = 8
#    test_loss  test_precision  test_recall  test_F-0.5  test_runtime  \
# 0   0.293452             1.0     0.357143    0.735294       28.4674
#
#    test_samples_per_second  test_steps_per_second
# 0                    3.443                  0.457

# %%
get_summary_report('reliability',test_df.reliability,reliability_test)
# Out:
# - There were 14 reliability cases
# - The model made 5 predictions
# - 5 were accurate

# %%
#Generate the confusion matrix
reliability_test_true = test_df.reliability.tolist()
reliability_test_preds = np.argmax(reliability_test[0], axis=1).flatten()
reliability_cm = confusion_matrix(test_df.reliability, reliability_test_preds)
reliability_disp = ConfusionMatrixDisplay(confusion_matrix=reliability_cm)

#Plot the confusion matrix
with plt.style.context(['notebook','no-latex']):
    reliability_disp.plot(cmap='Blues',ax=None)
    plt.grid(False)
    plt.show()

# %% [markdown]
# #### • View misclassified tweets

# %%
reliability_test_df = test_df[['Text','reliability']]
reliability_test_df['model_preds'] = reliability_test_preds 
reliability_misclassified = reliability_test_df[reliability_test_df.reliability != reliability_test_df.model_preds]

with pd.option_context('display.max_colwidth', None):
  display(reliability_misclassified)
# Out:
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                                                                                                                                                                               Text  \
# 43                                                                                           5 days of no internet tizeti wifisupport1 and our subscription is still running. i wonder how you guys sleep at night
# 108                                                                       tizeti oi my wifi hasn't worked in two days now. location: yaba send help efforts to reach you via telephone have been fruitless so far.
# 93   tizeti after singing their praise for a time...my eyes now look to other reliable data options...it's beginning to be a very terrible experience...one calls/emails customer support daily for various issues
# 80                                                                                                      spectranet_ng is just so unreliable for me. wish i did enough due diligence before getting into this one .
# 103                                                                                                                                                        aweola7 tizeti taking their unreliable service to ghana
# 20                                                                                                                                                                 day or night spectranet_ng remain useless 🤦🏽‍♂️
# 246                                                                                                                  davidiadeleke swiftnetworksng same with spectranet_ng. they've all been terrible this period!
# 330                                                                                               tizeti i'm not enjoying this network. subscribed for 2months so i can work from home but it's really frustrating
# 164                                                                                        i'm using spectranet o but the network has been shit since last week, i don sub for my glo twice in one week already 😭😭
#
#      reliability  model_preds
# 43             1            0
# 108            1            0
# 93             1            0
# 80             1            0
# 103            1            0
# 20             1            0
# 246            1            0
# 330            1            0
# 164            1            0

# %% [markdown]
# Misclassifications seem pretty obvious. It especially misses the cases where the word unreliable is used! Might be helpful to encode this information better into the model

# %% [markdown]
# ---

# %% [markdown]
# ### Coverage Aspect Classifier

# %% [markdown]
# #### a. Encode the training, validation and test sets

# %%
#Prepare the Training set
coverage_train_dataset = Generate_PyTorch_Dataset(
    texts         = train_df.Text.tolist(),
    aspect_labels = train_df.coverage.tolist(),
    tokenizer     = TOKENIZER
)

#Prepare the validation set
coverage_val_dataset = Generate_PyTorch_Dataset(
    texts           = val_df.Text.tolist(),
    aspect_labels   = val_df.coverage.tolist(),
    tokenizer       = TOKENIZER
)

# Prepare the test set
coverage_test_dataset = Generate_PyTorch_Dataset(
    texts          = test_df.Text.tolist(),
    aspect_labels  = test_df.coverage.tolist(),
    tokenizer      = TOKENIZER
)

# %% [markdown]
# #### b. Training/finetuning the bertweet model for the coverage aspect
# We reweight the loss function given the extreme imbalance as shown below. This is even worse than for the reliability aspect

# %%
with plt.style.context(['notebook','no-latex','grid']):
    train_df.coverage.value_counts().plot(kind='barh')
    plt.ylabel('Coverage aspect label', fontsize=16)
    plt.xlabel('Number of tweets', fontsize=16)

# %%
#Define the training parameters
coverage_training_args = TrainingArguments(
    output_dir                  = "../models/absa-aspect-extraction/ensemble_model/coverage_classifier",
    num_train_epochs            = 15,
    seed                        = 29,
    per_device_train_batch_size = 32, #Increase training batch size to ensure that each batch has a decent chance of containing a few positive samples.
    warmup_steps                = 500, #Add warmup steps since this is an entirely new problem domain for this pretrained model
    save_total_limit            = 3,
    load_best_model_at_end      = True,
    metric_for_best_model       = 'F-0.5',    
    save_strategy               = "epoch",
    logging_strategy            = "epoch",
    evaluation_strategy         = "epoch"
)    
    
#Define Trainer object
coverage_trainer = BinaryRelevanceTrainer(
    no_of_classes   = len(train_df.coverage.unique()),
    samples_per_cls = train_df.coverage.value_counts(sort=False).to_list(),
    model           = BERTWEET_MODEL,
    args            = coverage_training_args,
    train_dataset   = coverage_train_dataset,
    eval_dataset    = coverage_val_dataset,
    compute_metrics = compute_metrics
)


#Start pre-training!
coverage_trainer.train()
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# ***** Running training *****
#   Num examples = 292
#   Num Epochs = 15
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 150
#     <div>
#
#       <progress value='150' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [150/150 1:14:40, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F-0.5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.593900</td>
#       <td>0.572794</td>
#       <td>0.142857</td>
#       <td>0.222222</td>
#       <td>0.153846</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.518800</td>
#       <td>0.541303</td>
#       <td>0.166667</td>
#       <td>0.222222</td>
#       <td>0.175439</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.539500</td>
#       <td>0.523416</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.473800</td>
#       <td>0.532984</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.513200</td>
#       <td>0.516223</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.391100</td>
#       <td>0.498133</td>
#       <td>0.250000</td>
#       <td>0.333333</td>
#       <td>0.263158</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.328600</td>
#       <td>0.502490</td>
#       <td>0.222222</td>
#       <td>0.222222</td>
#       <td>0.222222</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.281300</td>
#       <td>0.391844</td>
#       <td>0.315789</td>
#       <td>0.666667</td>
#       <td>0.352941</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.138900</td>
#       <td>0.591224</td>
#       <td>0.500000</td>
#       <td>0.222222</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.143000</td>
#       <td>0.502450</td>
#       <td>0.625000</td>
#       <td>0.555556</td>
#       <td>0.609756</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.063100</td>
#       <td>0.502012</td>
#       <td>0.714286</td>
#       <td>0.555556</td>
#       <td>0.675676</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.040600</td>
#       <td>0.829369</td>
#       <td>0.500000</td>
#       <td>0.222222</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.021900</td>
#       <td>0.582739</td>
#       <td>0.714286</td>
#       <td>0.555556</td>
#       <td>0.675676</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.014300</td>
#       <td>0.663493</td>
#       <td>0.571429</td>
#       <td>0.444444</td>
#       <td>0.540541</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.009700</td>
#       <td>0.692015</td>
#       <td>0.666667</td>
#       <td>0.444444</td>
#       <td>0.606061</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-10
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-10/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-10/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-20
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-20/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-20/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-30
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-30/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-30/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-40
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-40/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-40/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-10] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-50
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-50/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-50/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-30] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-60
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-60/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-60/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-20] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-70
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-70/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-70/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-40] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-80
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-80/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-80/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-50] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-90
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-90/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-90/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-60] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-100
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-100/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-100/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-70] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-110
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-110/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-110/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-80] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-120
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-120/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-120/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-90] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-130
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-130/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-130/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-140
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-140/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-140/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-120] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-150
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-150/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-150/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-130] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-110 (score: 0.6756756756756758).
# TrainOutput(global_step=150, training_loss=0.2714415862659613, metrics={'train_runtime': 4510.4576, 'train_samples_per_second': 0.971, 'train_steps_per_second': 0.033, 'total_flos': 453787081943040.0, 'train_loss': 0.2714415862659613, 'epoch': 15.0})

# %% [markdown]
# ##### • Plot train and validation metrics

# %%
#Get the coverage (without weight decay) bertweet's training logs
coverage_history = pd.DataFrame(coverage_trainer.state.log_history)
coverage_history.to_csv("../model_logs/aspect_extraction/coverage_bertweet_logs.csv",index=False)

coverage_history = pd.read_csv("../model_logs/aspect_extraction/coverage_bertweet_logs.csv")
coverage_history = coverage_history.fillna(method='bfill', 
                                           limit=1).drop_duplicates(subset=['epoch','eval_loss'])

# %%
plt.figure(figsize=(15,9))

metrics = ['eval_loss','eval_F-0.5','eval_precision','eval_recall','eval_runtime']

for idx, metric in enumerate(metrics):
    with plt.style.context(['grid']):
        plt.tight_layout()
        ax = plt.subplot(3,2,idx+1).plot(coverage_history['epoch'],
                                         coverage_history[metric],
                                         label='validation')

        #Also plot training loss when plotting validation loss
        if metric == 'eval_loss':
            ax = plt.subplot(3,2,idx+1).plot(coverage_history['epoch'],
                                             coverage_history['loss'],
                                             color = ax[0].get_color(),
                                             linestyle= "--",
                                             label='training')

        plt.xlabel('Epoch', fontsize=12)
        plt.ylabel(metric.replace('eval_','').capitalize(),fontsize=12)
        plt.legend()

# %% [markdown]
# #### • Load the best checkpoint
#
# The best model on our metrics of interest: F-0.5 and precision appears to be the model from epoch 11 (**checkpoint-110**). Note that it performs very similarly to checkpoint-130 but has a lower validation loss

# %%
#Load the model
coverage_model = AutoModelForSequenceClassification.from_pretrained("../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-110")

coverage_pred_args = TrainingArguments(
    output_dir = "../model_predictions",
    do_predict = True
)

coverage_predictor = Trainer(
    model             = coverage_model,
    args              = coverage_pred_args,
    compute_metrics   = compute_metrics,
)
# Out:
# loading configuration file ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-110/config.json
# Model config RobertaConfig {
#   "_name_or_path": "vinai/bertweet-base",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 130,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "tokenizer_class": "BertweetTokenizer",
#   "transformers_version": "4.8.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 64001
# }
#
# loading weights file ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-110/pytorch_model.bin
# All model checkpoint weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the model checkpoint at ../models/absa-aspect-extraction/ensemble_model/coverage_classifier/checkpoint-110.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %% [markdown]
# #### • Evaluating the model: How well does it classify tweets?

# %% [markdown]
# **Training set**

# %%
coverage_train = coverage_predictor.predict(coverage_train_dataset, metric_key_prefix= 'train')
pd.DataFrame([coverage_train[-1]])
# Out:
# ***** Running Prediction *****
#   Num examples = 292
#   Batch size = 8
#     <div>
#
#       <progress value='63' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [37/37 05:02]
#     </div>
#    train_loss  train_precision  train_recall  train_F-0.5  train_runtime  \
# 0    0.036374         0.862069           1.0     0.886525         74.434
#
#    train_samples_per_second  train_steps_per_second
# 0                     3.923                   0.497

# %% [markdown]
# Recalls all samples correctly but predicts some wrongly

# %% [markdown]
# **Validation set**

# %%
coverage_validation = coverage_predictor.predict(coverage_val_dataset, metric_key_prefix= 'val')
pd.DataFrame([coverage_validation[-1]])
# Out:
# ***** Running Prediction *****
#   Num examples = 98
#   Batch size = 8
#    val_loss  val_precision  val_recall  val_F-0.5  val_runtime  \
# 0  0.230928       0.714286    0.555556   0.675676      26.1563
#
#    val_samples_per_second  val_steps_per_second
# 0                   3.747                 0.497

# %%
get_summary_report('coverage',val_df.coverage,coverage_validation)
# Out:
# - There were 9 coverage cases
# - The model made 7 predictions
# - 5 were accurate

# %% [markdown]
# Fair performance

# %% [markdown]
# **Test set**

# %%
coverage_test = coverage_predictor.predict(coverage_test_dataset, metric_key_prefix= 'test')
pd.DataFrame([coverage_test[-1]])
# Out:
# ***** Running Prediction *****
#   Num examples = 98
#   Batch size = 8
#    test_loss  test_precision  test_recall  test_F-0.5  test_runtime  \
# 0   0.436776        0.166667     0.111111    0.151515       26.5803
#
#    test_samples_per_second  test_steps_per_second
# 0                    3.687                  0.489

# %%
get_summary_report('coverage',test_df.coverage,coverage_test)
# Out:
# - There were 9 reliability cases
# - The model made 6 predictions
# - 1 were accurate

# %% [markdown]
# Performs extremely poorly on the test set

# %%
#Generate the confusion matrix
coverage_test_true = test_df.coverage.tolist()
coverage_test_preds = np.argmax(coverage_test[0], axis=1).flatten()
coverage_cm = confusion_matrix(coverage_test_true, coverage_test_preds)
coverage_disp = ConfusionMatrixDisplay(confusion_matrix=coverage_cm)

#Plot the confusion matrix
with plt.style.context(['notebook','no-latex']):
    coverage_disp.plot(cmap='Blues',ax=None)
    plt.grid(False)
    plt.show()

# %% [markdown]
# #### • View misclassified tweets

# %%
coverage_test_df = test_df[['Text','coverage']]
coverage_test_df['model_preds'] = coverage_test_preds 
coverage_misclassified = coverage_test_df[coverage_test_df.coverage != coverage_test_df.model_preds]

with pd.option_context('display.max_colwidth', None):
  display(coverage_misclassified)
# Out:
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                                                                                                                                                                                                      Text  \
# 89                                                                                                                                                             spectranet_ng hello please can i add multiple devices to the same account?
# 43                                                                                                                  5 days of no internet tizeti wifisupport1 and our subscription is still running. i wonder how you guys sleep at night
# 23                                                                                                                      please, am i good to go with spectranet in lagos. is their network strong in lagos. asking for myself. educate me
# 226  hello spectranet_ng, your network for over a week in surulere has been extremely crappy. what exactly is going on? i mean i can't do things at a fast rate and it's stressing me out. can you rectify it as soon as possible? thanks
# 287  spectranet_ng globacomnigeria i have sent you something on the frustrating experience through your seflcare portal after several complaints and a visit to your bode thomas office. pls fix it today and forever...otherwise, i port
# 78                                                                                                                              i am having terrible experience using spectranet_ng today, poor or no internet is what i am getting. sigh
# 170                                                                                                                                      why is it that everyone has to hang their spectranet mifis on their windows for it to work? ehn?
# 54              i've tried spectranet, smile, swift, tizeti(🤮). for their flaws, ntel was providing truly unlimited and relatively fast internet, and they are available in lagos and abuja. with this fup thing, i want to have options.
# 217                                                 myaccessbank hi please made a deposit into my sister's spectranet_ng account via the #accessmore app got an error and was debited but yet to see the money in the #spectranet account
# 77                                            spectranet_ng hi, i collected my sister's mifi before traveling. i am not able to recharge or subscribe because i don't know the sim number, nor the user id credentials. how can you help?
# 166                                                                                                                                         spectranet_ng , see no make me swear for you! fix your wacky internet connection around yaba!
# 285                                                                                                                                                               eyitayofajinmi spectranet_ng very poor coverage in ikate. very poor 💔💔💔
# 82                                                                       evaalordiah spectranet_ng is good but also depends on your location. but once you have good coverage you will enjoy it. and they are very generous with bonuses😜
#
#      coverage  model_preds
# 89          0            1
# 43          1            0
# 23          1            0
# 226         0            1
# 287         0            1
# 78          1            0
# 170         1            0
# 54          1            0
# 217         0            1
# 77          0            1
# 166         1            0
# 285         1            0
# 82          1            0

# %% [markdown]
# At this point. It really looks like random guessing. Again, it misses cases that reference the particular word. This increasingly suggests that it would be valuable to encode the aspect word into the model somehow. A possible alteration could be to utilize a hybrid approach which implements a lexicon dictionary of relevant words for aspect extraction.

# %% [markdown]
# ---

# %% [markdown]
# ### Price Aspect Classifier

# %% [markdown]
# #### a. Encode the training, validation and test sets

# %%
#Prepare the Training set
price_train_dataset = Generate_PyTorch_Dataset(
    texts         = train_df.Text.tolist(),
    aspect_labels = train_df.price.tolist(),
    tokenizer     = TOKENIZER
)

#Prepare the validation set
price_val_dataset = Generate_PyTorch_Dataset(
    texts           = val_df.Text.tolist(),
    aspect_labels   = val_df.price.tolist(),
    tokenizer       = TOKENIZER
)

# Prepare the test set
price_test_dataset = Generate_PyTorch_Dataset(
    texts          = test_df.Text.tolist(),
    aspect_labels  = test_df.price.tolist(),
    tokenizer      = TOKENIZER
)

# %% [markdown]
# #### b. Training/finetuning the bertweet model for the price aspect
# We reweight the loss function given the extreme imbalance as shown below:

# %%
with plt.style.context(['notebook','no-latex','grid']):
    train_df.price.value_counts().plot(kind='barh')
    plt.ylabel('Price aspect label', fontsize=16)
    plt.xlabel('Number of tweets', fontsize=16)

# %%
#Define the training parameters
price_training_args = TrainingArguments(
    output_dir                  = "../models/absa-aspect-extraction/ensemble_model/price_classifier",
    num_train_epochs            = 20,
    seed                        = 166,
    per_device_train_batch_size = 32, #Increase training batch size to ensure that each batch has a decent chance of containing a few positive samples.
    #warmup_steps                = 500, #Add warmup steps since this is an entirely new problem domain for this pretrained model
    save_total_limit            = 3,
    load_best_model_at_end      = True,
    metric_for_best_model       = 'F-0.5',    
    save_strategy               = "epoch",
    logging_strategy            = "epoch",
    evaluation_strategy         = "epoch"
)    
    
#Define Trainer object
price_trainer = BinaryRelevanceTrainer(
    no_of_classes   = len(train_df.price.unique()),
    samples_per_cls = train_df.price.value_counts(sort=False).to_list(),
    model           = BERTWEET_MODEL,
    args            = price_training_args,
    train_dataset   = price_train_dataset,
    eval_dataset    = price_val_dataset,
    compute_metrics = compute_metrics
)


#Start pre-training!
price_trainer.train()
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# ***** Running training *****
#   Num examples = 292
#   Num Epochs = 20
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 200
#     <div>
#
#       <progress value='200' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [200/200 1:51:28, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F-0.5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.594700</td>
#       <td>0.521835</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.499400</td>
#       <td>0.396460</td>
#       <td>0.434783</td>
#       <td>0.833333</td>
#       <td>0.480769</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.285300</td>
#       <td>0.233354</td>
#       <td>0.769231</td>
#       <td>0.833333</td>
#       <td>0.781250</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.149800</td>
#       <td>0.233201</td>
#       <td>0.714286</td>
#       <td>0.833333</td>
#       <td>0.735294</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.085700</td>
#       <td>0.425848</td>
#       <td>0.750000</td>
#       <td>0.500000</td>
#       <td>0.681818</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.056200</td>
#       <td>0.315880</td>
#       <td>0.666667</td>
#       <td>0.833333</td>
#       <td>0.694444</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.013200</td>
#       <td>0.336953</td>
#       <td>0.818182</td>
#       <td>0.750000</td>
#       <td>0.803571</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.008800</td>
#       <td>0.325221</td>
#       <td>0.818182</td>
#       <td>0.750000</td>
#       <td>0.803571</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.006300</td>
#       <td>0.298021</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.005000</td>
#       <td>0.309622</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.004200</td>
#       <td>0.318102</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.003700</td>
#       <td>0.324388</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.003300</td>
#       <td>0.329221</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.003000</td>
#       <td>0.333173</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.002900</td>
#       <td>0.336534</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.002700</td>
#       <td>0.339260</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.002500</td>
#       <td>0.341596</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.002500</td>
#       <td>0.343101</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.002400</td>
#       <td>0.344049</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.002400</td>
#       <td>0.344394</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#       <td>0.833333</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-10
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-10/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-10/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-20
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-20/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-20/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-30
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-30/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-30/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-110] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-40
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-40/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-40/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-10] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-50
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-50/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-50/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-20] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-60
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-60/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-60/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-40] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-70
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-70/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-70/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-30] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-80
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-80/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-80/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-50] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-90
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-90/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-90/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-60] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-100
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-100/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-100/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-70] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-110
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-110/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-110/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-80] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-120
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-120/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-120/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-130
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-130/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-130/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-110] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-140
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-140/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-140/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-120] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-150
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-150/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-150/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-130] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-160
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-160/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-160/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-140] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-170
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-170/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-170/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-150] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-180
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-180/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-180/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-160] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-190
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-190/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-190/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-170] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-200
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-200/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-200/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-180] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-90 (score: 0.8333333333333334).
# TrainOutput(global_step=200, training_loss=0.08671132196672261, metrics={'train_runtime': 6724.7478, 'train_samples_per_second': 0.868, 'train_steps_per_second': 0.03, 'total_flos': 605049442590720.0, 'train_loss': 0.08671132196672261, 'epoch': 20.0})

# %% [markdown]
# I'm already very pessimistic about this model

# %% [markdown]
# ##### • Plot train and validation metrics

# %%
#Get the price bertweet's training logs
price_history = pd.DataFrame(price_trainer.state.log_history)
price_history.to_csv("../model_logs/aspect_extraction/price_bertweet_logs.csv",index=False)

price_history = pd.read_csv("../model_logs/aspect_extraction/price_bertweet_logs.csv")
price_history = price_history.fillna(method='bfill', limit=1).drop_duplicates(subset=['epoch','eval_loss'])

# %%
plt.figure(figsize=(15,9))

metrics = ['eval_loss','eval_F-0.5','eval_precision','eval_recall','eval_runtime']

for idx, metric in enumerate(metrics):
    with plt.style.context(['grid']):
        plt.tight_layout()
        ax = plt.subplot(3,2,idx+1).plot(price_history['epoch'],
                                         price_history[metric],
                                         label='validation')

        #Also plot training loss when plotting validation loss
        if metric == 'eval_loss':
            ax = plt.subplot(3,2,idx+1).plot(price_history['epoch'],
                                             price_history['loss'],
                                             color = ax[0].get_color(),
                                             linestyle= "--",
                                             label='training')

        plt.xlabel('Epoch', fontsize=12)
        plt.ylabel(metric.replace('eval_','').capitalize(),fontsize=12)
        plt.legend()

# %% [markdown]
# #### • Load the best checkpoint
#
# The best model on our metrics of interest: F-0.5 and precision appears to be the model from epoch 9 (**checkpoint-90**).

# %%
#Load the model
price_model = AutoModelForSequenceClassification.from_pretrained("../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-90")

price_pred_args = TrainingArguments(
    output_dir = "../model_predictions",
    do_predict = True
)

price_predictor = Trainer(
    model             = price_model,
    args              = price_pred_args,
    compute_metrics   = compute_metrics,
)
# Out:
# loading configuration file ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-90/config.json
# Model config RobertaConfig {
#   "_name_or_path": "vinai/bertweet-base",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 130,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "tokenizer_class": "BertweetTokenizer",
#   "transformers_version": "4.8.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 64001
# }
#
# loading weights file ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-90/pytorch_model.bin
# All model checkpoint weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the model checkpoint at ../models/absa-aspect-extraction/ensemble_model/price_classifier/checkpoint-90.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %% [markdown]
# #### • Evaluating the model: How well does it classify tweets?

# %% [markdown]
# **Training set**

# %%
price_train = price_predictor.predict(price_train_dataset, metric_key_prefix= 'train')
pd.DataFrame([price_train[-1]])
# Out:
# ***** Running Prediction *****
#   Num examples = 292
#   Batch size = 8
#     <div>
#
#       <progress value='63' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [37/37 12:22]
#     </div>
#    train_loss  train_precision  train_recall  train_F-0.5  train_runtime  \
# 0    0.003609              1.0           1.0          1.0        76.4287
#
#    train_samples_per_second  train_steps_per_second
# 0                     3.821                   0.484

# %% [markdown]
# Perfect training set prediction. Might this already hint at overfitting?

# %% [markdown]
# **Validation set**

# %%
price_validation = price_predictor.predict(price_val_dataset, metric_key_prefix= 'val')
pd.DataFrame([price_validation[-1]])
# Out:
# ***** Running Prediction *****
#   Num examples = 98
#   Batch size = 8
#    val_loss  val_precision  val_recall  val_F-0.5  val_runtime  \
# 0  0.230988       0.833333    0.833333   0.833333      25.0416
#
#    val_samples_per_second  val_steps_per_second
# 0                   3.913                 0.519

# %% [markdown]
# **Validation set classification report**

# %%
get_summary_report('price',val_df.price,price_validation)
# Out:
# - There were 12 price cases
# - The model made 12 predictions
# - 10 were accurate

# %% [markdown]
# Does a pretty good job

# %% [markdown]
# **Test set**

# %%
price_test = price_predictor.predict(price_test_dataset, metric_key_prefix= 'test')
pd.DataFrame([price_test[-1]])
# Out:
# ***** Running Prediction *****
#   Num examples = 98
#   Batch size = 8
#    test_loss  test_precision  test_recall  test_F-0.5  test_runtime  \
# 0   0.227898        0.833333     0.833333    0.833333       27.9978
#
#    test_samples_per_second  test_steps_per_second
# 0                      3.5                  0.464

# %%
get_summary_report('price',test_df.price,price_test)
# Out:
# - There were 12 price cases
# - The model made 12 predictions
# - 10 were accurate

# %% [markdown]
# Does pretty good

# %%
#Generate the confusion matrix
price_test_true = test_df.price.tolist()
price_test_preds = np.argmax(price_test[0], axis=1).flatten()
price_cm = confusion_matrix(price_test_true, price_test_preds)
price_disp = ConfusionMatrixDisplay(confusion_matrix=price_cm)

#Plot the confusion matrix
with plt.style.context(['notebook','no-latex']):
    price_disp.plot(cmap='Blues',ax=None)
    plt.grid(False)
    plt.show()

# %% [markdown]
# #### • View misclassified tweets

# %%
price_test_df = test_df[['Text','price']]
price_test_df['model_preds'] = price_test_preds 
price_misclassified = price_test_df[price_test_df.price != price_test_df.model_preds]

with pd.option_context('display.max_colwidth', None):
  display(price_misclassified)
# Out:
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                                                                                                                                                                                                                                                        Text  \
# 131                                                                                                                                                                                                      how can ngn5000 be just 7gig? spectranet this is becoming unhealthy. spectranet_ng
# 42                                                                                                                                                                                                                                                               aniruoje buy spectranet_ng
# 32   spectranet_ng your network has been the worst thing about this lockdown. instead of working to make the network better, you're focusing on how to make us pay. ordinary to update whatsapp status takes minutes. once this lockdown ends, dumping your shitty network will be my goal.
# 217                                                                                                   myaccessbank hi please made a deposit into my sister's spectranet_ng account via the #accessmore app got an error and was debited but yet to see the money in the #spectranet account
#
#      price  model_preds
# 131      1            0
# 42       1            0
# 32       0            1
# 217      0            1

# %% [markdown]
# Model's predictions are actually pretty valid! Could be definitely classified as price and so might be a case of me mislabelling!
#
# Also first example is a similar problems to the above. I think some feature engineering might be my best approach – encoding some of the knowledge I already have about all these aspects. People's lingo is also pretty restricted. They use a subset of words to refer to one thing

# %% [markdown]
# ---

# %% [markdown]
# ### Speed Aspect Classifier

# %%
#Load BerTweet tokenizer
SPEED_TOKENIZER = AutoTokenizer.from_pretrained("vinai/bertweet-base", normalization=True)

#Load the BERTweet model
SPEED_MODEL = AutoModelForSequenceClassification.from_pretrained("vinai/bertweet-base", 
                                                                    num_labels = 2, 
                                                                    from_tf = True)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# All TF 2.0 model weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the TF 2.0 model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.

# %% [markdown]
# #### a. Add relevant speed tokens to the tokenizer's vocabulary

# %%
#Note down internet speed-related tokens, so tokenizer does not split these
#special_speed_tokens_dict = {'additional_special_tokens': ['mbps','mb/s','kbps','kb/s','gbps','gb/s']}
SPEED_TOKENIZER.add_tokens(['mbps','mb/s','kbps','kb/s','gbps','gb/s'])

#Resize the token embedding matrix of bertweet so that its embedding matrix matches the tokenizer.
SPEED_MODEL.resize_token_embeddings(len(SPEED_TOKENIZER))
# Out:
# Embedding(64007, 768)

# %% [markdown]
# #### b. Encode the training, validation and test sets

# %%
#Prepare the Training set
speed_train_dataset = Generate_PyTorch_Dataset(
    texts         = train_df.Text.tolist(),
    aspect_labels = train_df.speed.tolist(),
    tokenizer     = SPEED_TOKENIZER
)

#Prepare the validation set
speed_val_dataset = Generate_PyTorch_Dataset(
    texts           = val_df.Text.tolist(),
    aspect_labels   = val_df.speed.tolist(),
    tokenizer       = SPEED_TOKENIZER
)

# Prepare the test set
speed_test_dataset = Generate_PyTorch_Dataset(
    texts          = test_df.Text.tolist(),
    aspect_labels  = test_df.speed.tolist(),
    tokenizer      = SPEED_TOKENIZER
)

# %% [markdown]
# #### c. Training/finetuning the bertweet model for the speed aspect
# We reweight the loss function given the extreme imbalance as shown below. This is even worse than for the reliability aspect

# %%
with plt.style.context(['notebook','no-latex','grid']):
    train_df.speed.value_counts().plot(kind='barh')
    plt.ylabel('Speed aspect label', fontsize=16)
    plt.xlabel('Number of tweets', fontsize=16)

# %%
#Define the training parameters
speed_training_args = TrainingArguments(
    output_dir                  = "../models/absa-aspect-extraction/ensemble_model/speed_classifier",
    num_train_epochs            = 15,
    seed                        = 99,
    per_device_train_batch_size = 32, #Increase training batch size to ensure that each batch has a decent chance of containing a few positive samples.
    warmup_steps                = 500, #Add warmup steps since this is an entirely new problem domain for this pretrained model
    save_total_limit            = 3,
    load_best_model_at_end      = True,
    metric_for_best_model       = 'F-0.5',    
    save_strategy               = "epoch",
    logging_strategy            = "epoch",
    evaluation_strategy         = "epoch"
)    
    
#Define Trainer object
speed_trainer = BinaryRelevanceTrainer(
    no_of_classes   = len(train_df.speed.unique()),
    samples_per_cls = train_df.speed.value_counts(sort=False).to_list(),
    model           = SPEED_MODEL,
    args            = speed_training_args,
    train_dataset   = speed_train_dataset,
    eval_dataset    = speed_val_dataset,
    compute_metrics = compute_metrics
)


#Start pre-training!
speed_trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 292
#   Num Epochs = 15
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 150
#     <div>
#
#       <progress value='150' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [150/150 1:21:31, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F-0.5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.666900</td>
#       <td>0.652960</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.662000</td>
#       <td>0.638425</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.655700</td>
#       <td>0.618133</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.633400</td>
#       <td>0.602338</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.618900</td>
#       <td>0.591535</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.612600</td>
#       <td>0.578491</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.580700</td>
#       <td>0.568390</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.594400</td>
#       <td>0.560365</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.555300</td>
#       <td>0.551207</td>
#       <td>0.500000</td>
#       <td>0.076923</td>
#       <td>0.238095</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.502800</td>
#       <td>0.513423</td>
#       <td>0.400000</td>
#       <td>0.153846</td>
#       <td>0.303030</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.389000</td>
#       <td>0.448042</td>
#       <td>0.500000</td>
#       <td>0.307692</td>
#       <td>0.444444</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.252900</td>
#       <td>0.442285</td>
#       <td>0.500000</td>
#       <td>0.230769</td>
#       <td>0.405405</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.145600</td>
#       <td>0.382946</td>
#       <td>0.727273</td>
#       <td>0.615385</td>
#       <td>0.701754</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.072500</td>
#       <td>0.331663</td>
#       <td>0.727273</td>
#       <td>0.615385</td>
#       <td>0.701754</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.041400</td>
#       <td>0.515198</td>
#       <td>0.700000</td>
#       <td>0.538462</td>
#       <td>0.660377</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-10
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-10/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-10/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-20
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-20/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-20/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-30
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-30/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-30/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-40
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-40/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-40/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-20] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-50
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-50/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-50/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-30] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-60
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-60/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-60/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-40] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-70
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-70/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-70/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-50] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-80
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-80/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-80/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-60] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-90
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-90/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-90/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-10] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-100
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-100/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-100/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-70] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-110
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-110/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-110/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-80] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-120
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-120/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-120/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-90] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-130
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-130/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-130/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-140
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-140/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-140/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-110] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-150
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-150/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-150/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-120] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-130 (score: 0.7017543859649122).
# TrainOutput(global_step=150, training_loss=0.4656094169616699, metrics={'train_runtime': 4924.5878, 'train_samples_per_second': 0.889, 'train_steps_per_second': 0.03, 'total_flos': 453802582517760.0, 'train_loss': 0.4656094169616699, 'epoch': 15.0})

# %% [markdown]
# Seems like it took the model a while to make any real learning progress (8 epochs)

# %%
#Get the speed bertweet's training logs
speed_history = pd.DataFrame(speed_trainer.state.log_history)
speed_history.to_csv("../model_logs/aspect_extraction/speed_bertweet_logs.csv",index=False)

speed_history = pd.read_csv("../model_logs/aspect_extraction/speed_bertweet_logs.csv")
speed_history = speed_history.fillna(method='bfill', limit=1).drop_duplicates(subset=['epoch','eval_loss'])

# %%
plt.figure(figsize=(15,9))

metrics = ['eval_loss','eval_F-0.5','eval_precision','eval_recall','eval_runtime']

for idx, metric in enumerate(metrics):
    with plt.style.context(['grid']):
        plt.tight_layout()
        ax = plt.subplot(3,2,idx+1).plot(speed_history['epoch'],
                                         speed_history[metric],
                                         label='validation')

        #Also plot training loss when plotting validation loss
        if metric == 'eval_loss':
            ax = plt.subplot(3,2,idx+1).plot(speed_history['epoch'],
                                             speed_history['loss'],
                                             color = ax[0].get_color(),
                                             linestyle= "--",
                                             label='training')

        plt.xlabel('Epoch', fontsize=12)
        plt.ylabel(metric.replace('eval_','').capitalize(),fontsize=12)
        plt.legend()

# %% [markdown]
# #### d. Continuing fine-tuning from best found epoch
# Not sure if this is a good thing to do as I am fine-tuning the checkpoint on data it was pretrained on? Could cause overfitting? I guess performance on the test set will tell true generalization ability (although might be an issue that test set is small).

# %%
#Load the best checkpoint from the last run
SPEED_MODEL2 = AutoModelForSequenceClassification.from_pretrained("../models/absa-aspect-extraction/ensemble_model/speed_classifier/check")

# %%
#FINE-TUNING:

#Define the training parameters
speed_training_args2 = TrainingArguments(
    output_dir                  = "../models/absa-aspect-extraction/ensemble_model/speed_classifier",
    num_train_epochs            = 15,
    seed                        = 99,
    per_device_train_batch_size = 32, #Increase training batch size to ensure that each batch has a decent chance of containing a few positive samples.
    save_total_limit            = 3,
    load_best_model_at_end      = True,
    metric_for_best_model       = 'F-0.5',    
    save_strategy               = "epoch",
    logging_strategy            = "epoch",
    evaluation_strategy         = "epoch"
)    
    
#Define Trainer object
speed_trainer2 = BinaryRelevanceTrainer(
    no_of_classes   = len(train_df.speed.unique()),
    samples_per_cls = train_df.speed.value_counts(sort=False).to_list(),
    model           = SPEED_MODEL2,
    args            = speed_training_args2,
    train_dataset   = speed_train_dataset,
    eval_dataset    = speed_val_dataset,
    compute_metrics = compute_metrics
)


#Start pre-training!
speed_trainer2.train()
# Out:
# ***** Running training *****
#   Num examples = 292
#   Num Epochs = 15
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 150
#     <div>
#
#       <progress value='150' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [150/150 1:21:51, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F-0.5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.138400</td>
#       <td>0.313226</td>
#       <td>0.687500</td>
#       <td>0.846154</td>
#       <td>0.714286</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.016400</td>
#       <td>0.736310</td>
#       <td>0.750000</td>
#       <td>0.461538</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.029300</td>
#       <td>0.577787</td>
#       <td>0.611111</td>
#       <td>0.846154</td>
#       <td>0.647059</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.030600</td>
#       <td>0.665136</td>
#       <td>0.888889</td>
#       <td>0.615385</td>
#       <td>0.816327</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.002100</td>
#       <td>0.371404</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.001600</td>
#       <td>0.398321</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.001300</td>
#       <td>0.406491</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.001100</td>
#       <td>0.580885</td>
#       <td>0.900000</td>
#       <td>0.692308</td>
#       <td>0.849057</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.004300</td>
#       <td>0.384361</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000900</td>
#       <td>0.418287</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000800</td>
#       <td>0.426352</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000800</td>
#       <td>0.430669</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000700</td>
#       <td>0.432771</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000700</td>
#       <td>0.433790</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000700</td>
#       <td>0.434052</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#       <td>0.846154</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-10
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-10/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-10/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-20
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-20/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-20/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-30
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-30/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-30/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-40
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-40/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-40/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-10] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-50
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-50/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-50/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-20] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-60
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-60/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-60/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-30] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-70
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-70/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-70/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-40] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-80
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-80/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-80/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-50] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-90
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-90/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-90/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-60] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-100
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-100/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-100/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-70] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-110
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-110/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-110/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-90] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-120
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-120/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-120/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-130
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-130/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-130/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-110] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-140
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-140/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-140/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-120] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-150
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-150/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-150/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-130] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-80 (score: 0.8490566037735849).
# TrainOutput(global_step=150, training_loss=0.015314764818176627, metrics={'train_runtime': 4943.9219, 'train_samples_per_second': 0.886, 'train_steps_per_second': 0.03, 'total_flos': 453802582517760.0, 'train_loss': 0.015314764818176627, 'epoch': 15.0})

# %%
#Get the speed bertweet's training logs
speed_history2 = pd.DataFrame(speed_trainer2.state.log_history)
speed_history2.to_csv("../model_logs/aspect_extraction/speed_bertweet_continued_logs.csv",index=False)

speed_history2 = pd.read_csv("../model_logs/aspect_extraction/speed_bertweet_continued_logs.csv")
speed_history2 = speed_history2.fillna(method='bfill', limit=1).drop_duplicates(subset=['epoch','eval_loss'])

# %%
plt.figure(figsize=(15,9))

metrics = ['eval_loss','eval_F-0.5','eval_precision','eval_recall','eval_runtime']

for idx, metric in enumerate(metrics):
    with plt.style.context(['grid']):
        plt.tight_layout()
        ax = plt.subplot(3,2,idx+1).plot(speed_history2['epoch'],
                                         speed_history2[metric],
                                         label='validation')

        #Also plot training loss when plotting validation loss
        if metric == 'eval_loss':
            ax = plt.subplot(3,2,idx+1).plot(speed_history2['epoch'],
                                             speed_history2['loss'],
                                             color = ax[0].get_color(),
                                             linestyle= "--",
                                             label='training')

        plt.xlabel('Epoch', fontsize=12)
        plt.ylabel(metric.replace('eval_','').capitalize(),fontsize=12)
        plt.legend()

# %% [markdown]
# Overfitting. Validation loss increasing while training loss decreasing. Got to a point when the model was pretty much not learning anymore

# %% [markdown]
# #### • Load the best checkpoint
# Taking all metrics (including validation loss) into account, the best checkpoint would be checkpoint-50. Unfortunately, due to the saving strategy, that checkpoint was not saved. The best model I have access to is that from epoch 15 (**checkpoint-15**)

# %%
#Load the model
speed_model = AutoModelForSequenceClassification.from_pretrained("../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-150")

speed_pred_args = TrainingArguments(
    output_dir = "../model_predictions",
    do_predict = True
)

speed_predictor = Trainer(
    model             = speed_model,
    args              = speed_pred_args,
    compute_metrics   = compute_metrics,
)
# Out:
# loading configuration file ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-150/config.json
# Model config RobertaConfig {
#   "_name_or_path": "../models/absa-aspect-extraction/ensemble_model/speed_classifier/check",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 130,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "tokenizer_class": "BertweetTokenizer",
#   "transformers_version": "4.8.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 64007
# }
#
# loading weights file ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-150/pytorch_model.bin
# All model checkpoint weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the model checkpoint at ../models/absa-aspect-extraction/ensemble_model/speed_classifier/checkpoint-150.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %% [markdown]
# #### • Evaluating the model: How well does it classify tweets?

# %% [markdown]
# **Training set**

# %%
speed_train = speed_predictor.predict(speed_train_dataset, metric_key_prefix= 'train')
pd.DataFrame([speed_train[-1]])
# Out:
# ***** Running Prediction *****
#   Num examples = 292
#   Batch size = 8
#     <div>
#
#       <progress value='63' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [37/37 06:50]
#     </div>
#    train_loss  train_precision  train_recall  train_F-0.5  train_runtime  \
# 0    0.000449              1.0           1.0          1.0        79.2604
#
#    train_samples_per_second  train_steps_per_second
# 0                     3.684                   0.467

# %% [markdown]
# Perfect training set prediction

# %% [markdown]
# **Validation set**

# %%
speed_validation = speed_predictor.predict(speed_val_dataset, metric_key_prefix= 'val')
pd.DataFrame([speed_validation[-1]])
# Out:
# ***** Running Prediction *****
#   Num examples = 98
#   Batch size = 8
#    val_loss  val_precision  val_recall  val_F-0.5  val_runtime  \
# 0  0.288885       0.846154    0.846154   0.846154      28.3673
#
#    val_samples_per_second  val_steps_per_second
# 0                   3.455                 0.458

# %% [markdown]
# **Validation set classification report**

# %%
get_summary_report('speed',val_df.speed,speed_validation)
# Out:
# - There were 13 speed cases
# - The model made 13 predictions
# - 11 were accurate

# %% [markdown]
# Does pretty great. Although I'm weary due to pretraining scheme. Test set will tell

# %% [markdown]
# **Test set**

# %%
speed_test = speed_predictor.predict(speed_test_dataset, metric_key_prefix= 'test')
pd.DataFrame([speed_test[-1]])
# Out:
# ***** Running Prediction *****
#   Num examples = 98
#   Batch size = 8
#    test_loss  test_precision  test_recall  test_F-0.5  test_runtime  \
# 0   0.187941             0.8     0.923077    0.821918       26.5102
#
#    test_samples_per_second  test_steps_per_second
# 0                    3.697                   0.49

# %%
get_summary_report('speed',test_df.speed,speed_test)
# Out:
# - There were 13 speed cases
# - The model made 15 predictions
# - 12 were accurate

# %% [markdown]
# Good job on the test set

# %%
#Generate the confusion matrix
speed_test_true = test_df.speed.tolist()
speed_test_preds = np.argmax(speed_test[0], axis=1).flatten()
speed_cm = confusion_matrix(speed_test_true, speed_test_preds)
speed_disp = ConfusionMatrixDisplay(confusion_matrix=speed_cm)

#Plot the confusion matrix
with plt.style.context(['notebook','no-latex']):
    speed_disp.plot(cmap='Blues',ax=None)
    plt.grid(False)
    plt.show()

# %% [markdown]
# #### • View misclassified tweets

# %%
speed_test_df = test_df[['Text','speed']]
speed_test_df['model_preds'] = speed_test_preds 
speed_misclassified = speed_test_df[speed_test_df.speed != speed_test_df.model_preds]

with pd.option_context('display.max_colwidth', None):
  display(speed_misclassified)
# Out:
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                                                                                                                                             Text  \
# 116                                                                tukooldegreat baba spectranet na scam, the 100gb finishes in 1 week, not as if i use the data to watch porn 😔
# 6              shame on you ntelng ntelcare you guys promised over 60mbps and look at what i am getting at a location close to unilag. i did rather just switch to spectranet_ng
# 330                                                             tizeti i'm not enjoying this network. subscribed for 2months so i can work from home but it's really frustrating
# 84   iiragtid onibada spectranet_ng ntelcare ntelng i think smilecomsng... the only reason i stopped the subscription is the cost.. to expensive... but the quality is top notch
#
#      speed  model_preds
# 116      0            1
# 6        1            0
# 330      0            1
# 84       0            1

# %% [markdown]
# Not very happy with these misclassifications

# %%
speed_classified_correct = speed_test_df[speed_test_df.speed == speed_test_df.model_preds]

with pd.option_context('display.max_colwidth', None):
  display(speed_classified_correct[speed_classified_correct.speed==1])
# Out:
#                                                                                                                                                                                                                                                                                                  Text  \
# 72                                                                                                                                                    tizeti is a special brand of useless, when it comes to this isp business. wifi dey, why am i buying mobile data to download whatsapp video fgs?
# 101                                                                                                                                                                                              who has fast internet and lives in yaba? biko help me, spectranet_ng is taking a whole fucking piss.
# 32             spectranet_ng your network has been the worst thing about this lockdown. instead of working to make the network better, you're focusing on how to make us pay. ordinary to update whatsapp status takes minutes. once this lockdown ends, dumping your shitty network will be my goal.
# 323                                                                                                                                                                                                      tizeti your network is trash... i can't open any website, netflix can't load on the tv. phew
# 226                                                              hello spectranet_ng, your network for over a week in surulere has been extremely crappy. what exactly is going on? i mean i can't do things at a fast rate and it's stressing me out. can you rectify it as soon as possible? thanks
# 54                                                                          i've tried spectranet, smile, swift, tizeti(🤮). for their flaws, ntel was providing truly unlimited and relatively fast internet, and they are available in lagos and abuja. with this fup thing, i want to have options.
# 17                                                                                                                                                                                                                                2gb file, spectranet day tell me 4hrs to download for midnight 😂😂😂😂
# 77                                                                                                                                                                                                                                      spectranet and etisalat are moving mad tonight.. why so slow😭
# 38   bigtt76 tizeti that's me! i signed up for an online masters course 4th of february, i got their internet 8th of february, and till today i haven't been able to watch a single video lecture. i've dropped out of the course! after promising 5mbps, they supplied 11kbps and asked me to renew.
# 341                                                                                                                                                                                                                              spectranet_ng had to switch to my mobile network to send this tweet.
# 3                                                                                                                                                                                                    spectranet data management tips always make me laugh with 25kb/s? the speed is my data manager 😂
# 10                                                                                                                                                                                                       spectranet_ng , una give us 1gb and take speed, pls take your 1gb and return back the speed.
#
#      speed  model_preds
# 72       1            1
# 101      1            1
# 32       1            1
# 323      1            1
# 226      1            1
# 54       1            1
# 17       1            1
# 77       1            1
# 38       1            1
# 341      1            1
# 3        1            1
# 10       1            1

# %% [markdown]
# #### • Test runs

# %%
pipe = TextClassificationPipeline(model=speed_model, tokenizer=SPEED_TOKENIZER, return_all_scores=True)
pipe("Why is the internet terribly slow??")
# Out:
# [[{'label': 'LABEL_0', 'score': 0.0005401621456257999},
#   {'label': 'LABEL_1', 'score': 0.9994598627090454}]]

# %%
pipe("50mbps is ridiculous")
# Out:
# [[{'label': 'LABEL_0', 'score': 0.9988399147987366},
#   {'label': 'LABEL_1', 'score': 0.0011600770521908998}]]

# %% [markdown]
# Still work to be done because it has not learnt the speed metrics. Could create dataset with just speed metrics as strings and retrain model

# %% [markdown]
# ---

# %% [markdown]
# ### Customer Service Aspect Classifier

# %% [markdown]
# #### a. Encode the training, validation and test sets

# %%
#Prepare the Training set
cs_train_dataset = Generate_PyTorch_Dataset(
    texts         = train_df.Text.tolist(),
    aspect_labels = train_df['customer service'].tolist(),
    tokenizer     = TOKENIZER
)

#Prepare the validation set
cs_val_dataset = Generate_PyTorch_Dataset(
    texts           = val_df.Text.tolist(),
    aspect_labels   = val_df['customer service'].tolist(),
    tokenizer       = TOKENIZER
)

# Prepare the test set
cs_test_dataset = Generate_PyTorch_Dataset(
    texts          = test_df.Text.tolist(),
    aspect_labels  = test_df['customer service'].tolist(),
    tokenizer      = TOKENIZER
)

# %% [markdown]
# #### b. Training/finetuning the bertweet model for the customer service aspect
# We reweight the loss function given the extreme imbalance as shown below. This is even worse than for the reliability aspect

# %%
with plt.style.context(['notebook','no-latex','grid']):
    train_df['customer service'].value_counts().plot(kind='barh')
    plt.ylabel('Speed aspect label', fontsize=16)
    plt.xlabel('Number of tweets', fontsize=16)

# %%
#Define the training parameters
customer_service_training_args = TrainingArguments(
    output_dir                  = "../models/absa-aspect-extraction/ensemble_model/customer_service_classifier",
    num_train_epochs            = 20,
    seed                        = 333,
    per_device_train_batch_size = 32, #Increase training batch size to ensure that each batch has a decent chance of containing a few positive samples.
    #warmup_steps                = 500, #Add warmup steps since this is an entirely new problem domain for this pretrained model
    save_total_limit            = 3,
    load_best_model_at_end      = True,
    metric_for_best_model       = 'F-0.5',
    save_strategy               = "epoch",
    logging_strategy            = "epoch",
    evaluation_strategy         = "epoch"
)    
    
#Define Trainer object
customer_service_trainer = BinaryRelevanceTrainer(
    no_of_classes   = len(train_df['customer service'].unique()),
    samples_per_cls = train_df['customer service'].value_counts(sort=False).to_list(),
    model           = BERTWEET_MODEL,
    args            = customer_service_training_args,
    train_dataset   = cs_train_dataset,
    eval_dataset    = cs_val_dataset,
    compute_metrics = compute_metrics
)


#Start pre-training!
customer_service_trainer.train()
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# ***** Running training *****
#   Num examples = 292
#   Num Epochs = 20
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 200
#     <div>
#
#       <progress value='200' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [200/200 2:11:35, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F-0.5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.267900</td>
#       <td>0.657639</td>
#       <td>0.378378</td>
#       <td>0.875000</td>
#       <td>0.426829</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.386200</td>
#       <td>1.145146</td>
#       <td>0.666667</td>
#       <td>0.250000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.150500</td>
#       <td>0.701137</td>
#       <td>0.588235</td>
#       <td>0.625000</td>
#       <td>0.595238</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.231400</td>
#       <td>0.659686</td>
#       <td>0.615385</td>
#       <td>0.500000</td>
#       <td>0.588235</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.109200</td>
#       <td>0.816629</td>
#       <td>0.588235</td>
#       <td>0.625000</td>
#       <td>0.595238</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.092500</td>
#       <td>0.720185</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.053300</td>
#       <td>0.921986</td>
#       <td>0.571429</td>
#       <td>0.500000</td>
#       <td>0.555556</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.018000</td>
#       <td>0.911981</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.011000</td>
#       <td>1.274370</td>
#       <td>0.583333</td>
#       <td>0.437500</td>
#       <td>0.546875</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.004600</td>
#       <td>1.633214</td>
#       <td>0.500000</td>
#       <td>0.312500</td>
#       <td>0.446429</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.003800</td>
#       <td>1.594051</td>
#       <td>0.500000</td>
#       <td>0.375000</td>
#       <td>0.468750</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.003100</td>
#       <td>1.200573</td>
#       <td>0.600000</td>
#       <td>0.562500</td>
#       <td>0.592105</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.002600</td>
#       <td>1.151608</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.002400</td>
#       <td>1.165181</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.002200</td>
#       <td>1.178580</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.002000</td>
#       <td>1.189629</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.001900</td>
#       <td>1.198169</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.002000</td>
#       <td>1.201050</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.001900</td>
#       <td>1.203595</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.001800</td>
#       <td>1.204728</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#       <td>0.625000</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-10
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-10/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-10/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-20
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-20/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-20/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-30
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-30/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-30/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-40
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-40/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-40/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-10] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-50
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-50/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-50/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-20] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-60
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-60/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-60/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-30] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-70
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-70/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-70/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-40] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-80
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-80/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-80/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-50] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-90
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-90/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-90/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-70] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-100
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-100/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-100/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-80] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-110
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-110/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-110/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-90] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-120
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-120/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-120/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-130
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-130/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-130/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-110] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-140
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-140/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-140/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-120] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-150
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-150/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-150/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-130] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-160
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-160/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-160/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-140] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-170
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-170/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-170/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-150] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-180
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-180/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-180/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-160] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-190
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-190/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-190/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-170] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 98
#   Batch size = 8
# Saving model checkpoint to ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-200
# Configuration saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-200/config.json
# Model weights saved in ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-200/pytorch_model.bin
# Deleting older checkpoint [../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-180] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-60 (score: 0.625).
# TrainOutput(global_step=200, training_loss=0.06741902555339038, metrics={'train_runtime': 7932.0399, 'train_samples_per_second': 0.736, 'train_steps_per_second': 0.025, 'total_flos': 605049442590720.0, 'train_loss': 0.06741902555339038, 'epoch': 20.0})

# %%
#Get the price bertweet's training logs
customer_service_history = pd.DataFrame(customer_service_trainer.state.log_history)
customer_service_history.to_csv("../model_logs/aspect_extraction/customer_service_bertweet_logs.csv",
                                index=False)

customer_service_history = pd.read_csv("../model_logs/aspect_extraction/customer_service_bertweet_logs.csv")
customer_service_history = customer_service_history.fillna(method='bfill', 
                                                           limit=1).drop_duplicates(subset=['epoch',
                                                                                            'eval_loss'])

# %%
plt.figure(figsize=(15,9))

metrics = ['eval_loss','eval_F-0.5','eval_precision','eval_recall','eval_runtime']

for idx, metric in enumerate(metrics):
    with plt.style.context(['grid']):
        plt.tight_layout()
        ax = plt.subplot(3,2,idx+1).plot(customer_service_history['epoch'],
                                         customer_service_history[metric],
                                         label='validation')

        #Also plot training loss when plotting validation loss
        if metric == 'eval_loss':
            ax = plt.subplot(3,2,idx+1).plot(customer_service_history['epoch'],
                                             customer_service_history['loss'],
                                             color = ax[0].get_color(),
                                             linestyle= "--",
                                             label='training')

        plt.xlabel('Epoch', fontsize=12)
        plt.ylabel(metric.replace('eval_','').capitalize(),fontsize=12)
        plt.legend()

# %% [markdown]
# #### • Load the best checkpoint
#
# The best model on our metrics of interest: F-0.5 and precision appears to be the model from epoch 6 (**checkpoint-60**). However, I select checkpoint-140 because the training loss is much lower (it did not underfit as was the case with checkpoint-60).

# %%
#Load the model
customer_service_model = AutoModelForSequenceClassification.from_pretrained("../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-140")

customer_service_pred_args = TrainingArguments(
    output_dir = "../model_predictions",
    do_predict = True
)

customer_service_predictor = Trainer(
    model             = customer_service_model,
    args              = customer_service_pred_args,
    compute_metrics   = compute_metrics,
)
# Out:
# loading configuration file ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-140/config.json
# Model config RobertaConfig {
#   "_name_or_path": "vinai/bertweet-base",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 130,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "tokenizer_class": "BertweetTokenizer",
#   "transformers_version": "4.8.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 64001
# }
#
# loading weights file ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-140/pytorch_model.bin
# All model checkpoint weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the model checkpoint at ../models/absa-aspect-extraction/ensemble_model/customer_service_classifier/checkpoint-140.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %% [markdown]
# #### • Evaluating the model: How well does it classify tweets?

# %% [markdown]
# **Training set**

# %%
customer_service_train = customer_service_predictor.predict(cs_train_dataset, metric_key_prefix= 'train')
pd.DataFrame([customer_service_train[-1]])
# Out:
# ***** Running Prediction *****
#   Num examples = 292
#   Batch size = 8
#     <div>
#
#       <progress value='63' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [37/37 16:29]
#     </div>
#    train_loss  train_precision  train_recall  train_F-0.5  train_runtime  \
# 0    0.039082         0.916667           1.0     0.932203        75.1755
#
#    train_samples_per_second  train_steps_per_second
# 0                     3.884                   0.492

# %% [markdown]
# **Validation set**

# %%
customer_service_validation = customer_service_predictor.predict(cs_val_dataset, metric_key_prefix= 'val')
pd.DataFrame([customer_service_validation[-1]])
# Out:
# ***** Running Prediction *****
#   Num examples = 98
#   Batch size = 8
#    val_loss  val_precision  val_recall  val_F-0.5  val_runtime  \
# 0  0.322017       0.647059      0.6875   0.654762      33.2527
#
#    val_samples_per_second  val_steps_per_second
# 0                   2.947                 0.391

# %% [markdown]
# Does better on the validation set.

# %%
get_summary_report('customer service',val_df['customer service'],customer_service_validation)
# Out:
# - There were 16 customer service cases
# - The model made 17 predictions
# - 11 were accurate

# %% [markdown]
# Does a pretty poor job with recalling the aspect. From the recall, it's clearly overpredicting no speed aspect

# %% [markdown]
# **Test set**

# %%
customer_service_test = customer_service_predictor.predict(cs_test_dataset, metric_key_prefix= 'test')
pd.DataFrame([customer_service_test[-1]])
# Out:
# ***** Running Prediction *****
#   Num examples = 98
#   Batch size = 8
#    test_loss  test_precision  test_recall  test_F-0.5  test_runtime  \
# 0     0.1836        0.714286     0.555556    0.675676       26.8313
#
#    test_samples_per_second  test_steps_per_second
# 0                    3.652                  0.485

# %%
get_summary_report('customer service',test_df['customer service'],customer_service_test)
# Out:
# - There were 9 customer service cases
# - The model made 7 predictions
# - 5 were accurate

# %% [markdown]
# Does okay. Better than chance atleast

# %%
#Generate the confusion matrix
customer_service_test_true = test_df['customer service'].tolist()
customer_service_test_preds = np.argmax(customer_service_test[0], axis=1).flatten()
cs_cm = confusion_matrix(customer_service_test_true, customer_service_test_preds)
cs_disp = ConfusionMatrixDisplay(confusion_matrix=cs_cm)

#Plot the confusion matrix
with plt.style.context(['notebook','no-latex']):
    cs_disp.plot(cmap='Blues',ax=None)
    plt.grid(False)
    plt.show()

# %% [markdown]
# #### • View misclassified tweets

# %%
cs_test_df = test_df[['Text','customer service']]
cs_test_df['model_preds'] = customer_service_test_preds 
cs_misclassified = cs_test_df[cs_test_df['customer service'] != cs_test_df.model_preds]

with pd.option_context('display.max_colwidth', None):
  display(cs_misclassified)
# Out:
# /Users/koredeakande/opt/anaconda3/envs/capstone/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                                                                                                                                                                                                                                    Text  \
# 83                        spectranet_ng hello..pls fix your network service on amusan street, puposola road, new oko-oba..it is terrible and frustrating..poor network since yesterday. i have complained repeatedly but your network in this area is always really bad
# 88                                                                                                                                                                       damolaonline wifisupport1 tizeti it's really emabarrasing that the service rendered is so poor
# 287                                spectranet_ng globacomnigeria i have sent you something on the frustrating experience through your seflcare portal after several complaints and a visit to your bode thomas office. pls fix it today and forever...otherwise, i port
# 110                                                                                                                                                                               i don't know why spectranet_ng has the shittiest customer service like it's just wild
# 123                                                                                                                                                                                     iamchrisani wifisupport1 boycottfrauds tizeti i hate their generic response 😡😡😡
# 186  just had an awesome customer service experience from spectranet_ng . david listened and found a way to make it work. his supervisor tunji (i think) was ace! this is why i stick with spectranet! keep up the great work and don't make me regret my words please!
#
#      customer service  model_preds
# 83                  1            0
# 88                  0            1
# 287                 1            0
# 110                 1            0
# 123                 0            1
# 186                 1            0

# %% [markdown]
# Again still missing cases that use the exact words corresponding to the aspect!

# %% [markdown]
# ---

# %% [markdown]
# ## 8. Modeling - Full ABSA
# **`Aspect extraction`| `Aspect sentiment prediction`**

# %% [markdown]
# ### a. Load the packages and libraries

# %%
#Load metrics for ABSA
from absa_metrics import binary_precision_recall_fscore, aspect_sentiment_accuracy

#Import package for aspect sentiment prediction
import aspect_based_sentiment_analysis as absa

#Load the ABSA sentiment model
nlp = absa.load()
# Out:
# 2021-12-06 19:13:09.060703: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Some layers from the model checkpoint at absa/classifier-rest-0.2 were not used when initializing BertABSClassifier: ['dropout_379']
# - This IS expected if you are initializing BertABSClassifier from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertABSClassifier from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of BertABSClassifier were not initialized from the model checkpoint at absa/classifier-rest-0.2 and are newly initialized: ['dropout_37']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### b. Define function to run full ABSA

# %%
def full_absa_prediction(df, col_name):
    
    """
    Function to perform ABSA on tweets. This is a two-part task of aspect extraction 
    and aspect sentiment prediction
    
    Inputs:
        - df (pd DataFrame): A pandas dataframe to perform annotation on
        - col_name (str): The specific column in the dataframe containing the tweets run absa on
        
    Output:
        - absa_df (pd DataFrame): DataFrame containing the tweets and the ABSA results
    
    """
    
    #List to store detected aspects and their sentiments
    df_list = []
    
    #List containing the binary classifiers
    binary_classifiers = [('reliability',reliability_model),
                          ('price',price_model),
                          ('speed',speed_model),
                          ('coverage',coverage_model),
                          ('customer service', customer_service_model)]
    
    #Iterate through all the tweets
    for tweet in df[col_name]:
        
        #List to store the aspects detected
        aspects_detected = []
        
        #List to store the sentiment values (Positive, Negative or Neutral) for the aspects
        detected_sentiments = []
        
        #Encode the tweet
        encoding = TOKENIZER.encode_plus(
            tweet,
            add_special_tokens=True,
            max_length=TOKENIZER.model_max_length,
            return_token_type_ids=False,
            padding="max_length",
            return_attention_mask=True,
            return_tensors='pt'
        )
        
        #Iterate through each of the binary classifiers
        for aspect,classifier in binary_classifiers:
            
            #Run each binary classifier on the tweet
            aspect_prediction = classifier(encoding["input_ids"], encoding["attention_mask"])
            aspect_prediction = np.argmax(aspect_prediction[0].flatten().detach().numpy())
            
            #If the aspect was predicted to be 1, record the aspect as being found in the tweet
            if aspect_prediction == 1:
                aspects_detected.append(aspect)
                
        if aspects_detected:
            #Next, carry out sentiment prediction on the aspects detected
            sentiment = nlp(tweet,aspects = aspects_detected)
            
            #Iterate through each aspect sentiment predicted results
            for senti_result in sentiment.examples:

                #Get the sentiment scores
                scores = np.array(senti_result.scores)

                #Find the max sentiment score (i.e. the predicted sentiment value)
                max_score = np.argmax(scores)

                #Record the sentiment (string) category for the aspect
                if max_score == 2:

                    detected_sentiments.append("Positive")

                elif max_score == 1:

                    detected_sentiments.append("Negative")

                else:

                    detected_sentiments.append("Neutral")


            #Add the detected aspects and sentiments from the sentence to the list
            df_list.append([tweet,aspects_detected,detected_sentiments])
            
        else:
            df_list.append([tweet,None,None])
        

    absa_df = pd.DataFrame(df_list, 
                       columns=[col_name,'Detected aspects','Predicted sentiment'])
    
    return absa_df

# %% [markdown]
# ### c. Run ABSA on the validation set

# %%
#Quick preview of the validation set
val_df.head()
# Out:
#                                                   Text  price  speed  \
# 338  officialkome_ spectranet_ng this people don fr...      0      0
# 329  ayomikun_o_ yoruba_dev spectranet_ng i'm.yet t...      0      0
# 215                            spectranet !!!!! 🤬🤬🤬🤬🤬🤬      0      0
# 93   after buying data see airtel telling me "now t...      0      0
# 169                                   spectranet ooooo      0      0
#
#      reliability  coverage  customer service Sentiment
# 338            0         0                 0    [None]
# 329            0         0                 0    [None]
# 215            0         0                 0    [None]
# 93             0         0                 0    [None]
# 169            0         0                 0    [None]

# %%
#Run the ABSA model
val_absa_results = full_absa_prediction(val_df, 'Text')

# %%
with pd.option_context('display.max_colwidth', None):
    display(val_absa_results)
# Out:
#                                                                                                                                                                                          Text  \
# 0                                                                                                              officialkome_ spectranet_ng this people don frustrate me finish kai. i'm tired
# 1                                                                                                 ayomikun_o_ yoruba_dev spectranet_ng i'm.yet to turn on mine today if i do i'd join in defs
# 2                                                                                                                                                                     spectranet !!!!! 🤬🤬🤬🤬🤬🤬
# 3   after buying data see airtel telling me "now that i have data, i should watch one tin one tin. are you people actually ok? it's kukuma not your fault, it's that crippled tizeti i blame.
# 4                                                                                                                                                                            spectranet ooooo
# ..                                                                                                                                                                                        ...
# 93                                                                                                     nothing as frustrating as terrible network and spectranet is taking the piss right now
# 94                         kusssman the_only_ayo mtnng glo__nig 9mobileng ntelng airtelnigeria spectranet_ng don't mind then,they just like to make life hard .......useless network provider
# 95                                                                                     tizeti tizeti is not a good isp i've been experiencing this for almost 48 hours and it still continues
# 96                                                                                                                                                                    shame on you spectranet
# 97                                                                                                                                                       what's wrong with spectranet?? 🤦🏽‍♂️
#
#    Detected aspects Predicted sentiment
# 0              None                None
# 1              None                None
# 2              None                None
# 3           [speed]          [Negative]
# 4              None                None
# ..              ...                 ...
# 93    [reliability]          [Negative]
# 94             None                None
# 95    [reliability]          [Negative]
# 96             None                None
# 97          [speed]          [Negative]
#
# [98 rows x 3 columns]

# %%
#Save the ABSA predictions
val_absa_results.to_csv("../model_predictions/binary_relevance_absa_val_preds.csv", index=False)

# %%
#If loading the results
val_absa_results = pd.read_csv("../model_predictions/binary_relevance_absa_val_preds.csv")

#Convert from string to list
# val_absa_results['Detected aspects'] = val_absa_results['Detected aspects'].apply(lambda x: eval(x) if isinstance(x,str) else x)
# val_absa_results['Predicted sentiment'] = val_absa_results['Predicted sentiment'].apply(lambda x: eval(x) if isinstance(x,str) else x)

# %% [markdown]
# ### d. Prepare the data for model evaluation

# %%
#Get the true results for the tweets the model predicted on
val_true = merged_absa_df[merged_absa_df.Text.isin(val_absa_results.Text)].reset_index()

#Append the true values to the dataframe
val_true_vs_preds = pd.merge(val_absa_results, val_true, on = 'Text').drop(columns='index')

#Fill NAs and Nones with [None]
val_true_vs_preds = val_true_vs_preds.apply(lambda s: s.fillna({i: [None] for i in val_true_vs_preds.index}))

#Convert from string to list
# val_true_vs_preds.Aspects = val_true_vs_preds.Aspects.apply(lambda x: eval(x) if isinstance(x,str) else x)
# val_true_vs_preds.Sentiment = val_true_vs_preds.Sentiment.apply(lambda x: eval(x) if isinstance(x,str) else x)

#Quick preview
val_true_vs_preds.head()
# Out:
#                                                 Text Detected aspects  \
# 0  officialkome_ spectranet_ng this people don fr...           [None]
# 1  ayomikun_o_ yoruba_dev spectranet_ng i'm.yet t...           [None]
# 2                            spectranet !!!!! 🤬🤬🤬🤬🤬🤬           [None]
# 3  after buying data see airtel telling me "now t...        ['speed']
# 4                                   spectranet ooooo           [None]
#
#   Predicted sentiment Aspects Sentiment
# 0              [None]  [None]    [None]
# 1              [None]  [None]    [None]
# 2              [None]  [None]    [None]
# 3        ['Negative']  [None]    [None]
# 4              [None]  [None]    [None]

# %% [markdown]
# ### e. Model Evaluation [Aspect Extraction]

# %%
#Calculate precision, recall and f-0.5
class_metrics, precision, recall, fscore = binary_precision_recall_fscore(
    val_true_vs_preds['Aspects'],
    val_true_vs_preds['Detected aspects'], 
    beta = 0.5)

print(f"Precision: {precision:.3f}  Recall: {recall:.3f} F-0.5: {fscore:.3f}")
# Out:
# Precision: 0.565  Recall: 0.426 F-0.5: 0.531

# %%
(pd.DataFrame(class_metrics).T).iloc[:,-3:]
# Out:
#                   Precision    Recall     F-0.5
# price              0.333333  0.333333  0.333333
# speed              0.400000  0.153846  0.303030
# reliability        0.800000  0.363636  0.645161
# coverage           0.714286  0.555556  0.675676
# customer service   0.647059  0.687500  0.654762

# %% [markdown]
# ### e. Model Evaluation [Aspect Sentiment Prediction]

# %%
aspect_accuracies,micro_accuracy,macro_accuracy=aspect_sentiment_accuracy(val_true_vs_preds['Aspects'],
                                                                          val_true_vs_preds['Detected aspects'],
                                                                          val_true_vs_preds['Sentiment'],
                                                                          val_true_vs_preds['Predicted sentiment'])

print(f"Micro accuracy:{micro_accuracy:.3f}   Macro accuracy:{macro_accuracy:.3f}")
# Out:
# Micro accuracy:0.846   Macro accuracy:0.782

# %%
(pd.DataFrame([aspect_accuracies]).T).rename(columns={0:'Accuracy'})
# Out:
#                   Accuracy
# price             0.500000
# speed             0.500000
# reliability       1.000000
# coverage          1.000000
# customer service  0.909091

# %% [markdown]
# ---

# %% [markdown]
# ### Validation set for evaluation

# %%
eval_val_df = pd.concat([val_df.reset_index().drop(columns='index').iloc[:,:-1],val_true_vs_preds[['Aspects','Sentiment']]],axis=1)

# %%
eval_val_df.head()
# Out:
#                                                 Text  price  speed  \
# 0  officialkome_ spectranet_ng this people don fr...      0      0
# 1  ayomikun_o_ yoruba_dev spectranet_ng i'm.yet t...      0      0
# 2                            spectranet !!!!! 🤬🤬🤬🤬🤬🤬      0      0
# 3  after buying data see airtel telling me "now t...      0      0
# 4                                   spectranet ooooo      0      0
#
#    reliability  coverage  customer service Aspects Sentiment
# 0            0         0                 0  [None]    [None]
# 1            0         0                 0  [None]    [None]
# 2            0         0                 0  [None]    [None]
# 3            0         0                 0  [None]    [None]
# 4            0         0                 0  [None]    [None]

# %%
eval_val_df.to_csv("../data/model-evaluation/validation_dataset.csv",index=False)

# %% [markdown]
# ### Test set for evaluation

# %%
#Get the test set with original annotation
test_true = merged_absa_df[merged_absa_df.Text.isin(test_df.Text)].reset_index()

#Append the original annotations to the binarized test set
test_true_binarized_with_original  = pd.merge(test_df.reset_index().drop(columns='index').iloc[:,:-1], 
                                              test_true,
                                              on = 'Text').drop(columns='index')

#Fill NAs and Nones with [None]
test_true_binarized_with_original = test_true_binarized_with_original.apply(lambda s: s.fillna({i: [None] for i in test_true_binarized_with_original.index}))

test_true_binarized_with_original
# Out:
#                                                  Text  price  speed  \
# 0   deejay_klem smilecomsng well this means i will...      0      0
# 1   myaccessbank hello please i can't seem to find...      0      0
# 2   spectranet_ng hello please can i add multiple ...      0      0
# 3                                  spectranet is shit      0      0
# 4   tizeti is a special brand of useless, when it ...      0      1
# ..                                                ...    ...    ...
# 93  spectranet_ng pls are you ppl still doing prom...      0      0
# 94        spectranet_ng is today double data please 😊      0      0
# 95  this game dey hungry me tonight but spectranet...      0      0
# 96  wifisupport1 tizeti after making me pay 12500 ...      1      0
# 97  officialbambam4 spectranet_ng they can never c...      0      0
#
#     reliability  coverage  customer service  Aspects   Sentiment
# 0             0         0                 0   [None]      [None]
# 1             0         0                 0   [None]      [None]
# 2             0         0                 0   [None]      [None]
# 3             0         0                 0   [None]      [None]
# 4             0         0                 0  [speed]  [Negative]
# ..          ...       ...               ...      ...         ...
# 93            0         0                 0   [None]      [None]
# 94            0         0                 0   [None]      [None]
# 95            0         0                 0   [None]      [None]
# 96            0         0                 0  [price]  [Negative]
# 97            0         0                 0   [None]      [None]
#
# [98 rows x 8 columns]

# %%
test_true_binarized_with_original.to_csv("../data/model-evaluation/test_dataset.csv",index=False)
